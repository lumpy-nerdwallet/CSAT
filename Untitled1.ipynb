# %%
import nltk, re, math, collections, lda, random
import numpy as np
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import time


LANGUAGE = "english"
STOPWORD_SET = (set(nltk.corpus.stopwords.words(LANGUAGE)) | set(['even', '.', ','])) - set(['who', 'why', 'how', 'where', 'when', 'what', 'whom']) 
FILENAME = "comments_raw_merged_with_page_data_190716.csv"
COLUMN_NAME = "message"

def is_ASCII_string(string):
    '''
        Checks if string is ASCII-decodeable. Always run on pre-processed csv files!
    '''
    try:
        string.decode('ascii')
        return True
    except:
        return False

def ascii_substituted(string):
    '''
        Substitutes string to make it ASCII-readable. Currently very exception-driven, 
        but if there's a good package that does the dirty work please let @Lumpy know.
    '''
    return string.replace("\\n", " ").replace("&amp;", "&").replace('&#039;', '\'').replace("&quot;", "\"").replace("&lt;", "<").replace("&gt;", ">").replace("\xe2\x80\x93", "-").replace("\xe2\x80\x99", "\'").strip()


### CLEAN YOUR DF!!
def get_message_list(data_frame, column_name = "message"):
    '''
        Given a pre-CLEANED and pre-subsetted data frame, gets the message set from the data frame.
    '''
    return [message for message_l in data_frame[[column_name]].values.tolist() for message in message_l]            


def is_eligible_word(token, stopwords = STOPWORD_SET, regex_string = "^[^a-zA-Z0-9]+"):
    '''
        Private helper function.
        Check if word is eligible to be a token (i.e. not a forbidden regex, or in the stopword set).
    '''
    pattern = re.compile(regex_string)
    if pattern.match(token) or token in stopwords: 
        return False
    return True


def append_NOTs(tokenized_message, stopwords = STOPWORD_SET):
    '''
        Private helper function to handle negations.
        Given a List of words, returns a List of words with nots appended to the right words.
    '''
    new_message = []
    for i in range(len(tokenized_message)):
        if tokenized_message[i] in set(["n\'t", "n\"t", "no", "not", "didnt"]) and i != (len(tokenized_message) - 1):
            j = i + 1
            while j < len(tokenized_message):
                if tokenized_message[j] not in stopwords:
                    tokenized_message[j] = "not_" + tokenized_message[j]
                    break
                j += 1
        else:
            new_message.append(tokenized_message[i])
    return new_message


def split_message_into_tokens(untokenized_message, ngram = 1, stopwords = STOPWORD_SET, regex_string = "^[^a-zA-Z0-9]+", handle_negations = True): 
    '''
        Splits ONE message in the list of messages into words/tokens, in the process doing the following:
        1) Changing to lowercase
        2) Dealing with negations
        3) N-gramming
        4) Lemmatizing
        5) Stopword-removal
        Input: String.
        Arguments: 
            ngram:              n in n-grams                        Default is 1
            stopwords           Set of stopwords to remove          Default is the global variable
            regex_string        String containing regex pattern     Default is "^[^a-zA-Z0-9]+"
            handle_negations:   Do you want negations handled?      Default is True
        Output: List of n-grams.
    '''
    wordnet_lemmatizer = nltk.stem.WordNetLemmatizer()
    # Split into tokens
    tokenized_message = nltk.word_tokenize(untokenized_message.lower())
    # Deal with "not"s
    if handle_negations:
        tokenized_message = append_NOTs(tokenized_message, stopwords)
    # Lemmatize, n-gram, stopword-removal.
    if ngram == 1:
        return [wordnet_lemmatizer.lemmatize(token) for token in tokenized_message if is_eligible_word(token, stopwords, regex_string)]
    else:
        tokenized_message = ngrams(tokenized_message, ngram)
        return [[wordnet_lemmatizer.lemmatize(token) for token in ngram_indiv if is_eligible_word(token, stopwords, regex_string) not in stopwords] for ngram_indiv in tokenized_message if len(ngram_indiv) > 0]


def tokenize(message_list, ngram = 1, stopwords = STOPWORD_SET, regex_string = "^[^?a-zA-Z0-9]+", handle_negations = True, pos_tagset = "no-pos"):
    '''
        Tokenizes a list of strings. Assumes that message_list has been preprocessed.
        Input: List of Strings.
        Arguments:
            ngram               n in n-grams                                                                                Default is 1
            stopwords:          Set of stopwords to remove.                                                                 Default is the global variable.
            regex_string        String containing regex pattern                                                             Default is "^[^a-zA-Z0-9]+"
            handle_negations:   Do you want "not X" to be glued as "not_X"? Improves sentiment recognition.                 Default is True
            pos_tagset:         For POS tagging. Current options are "universal", None (which maps to nltk.pos_tag) 
                                and "no-pos", which really means no POS tagging. Only applicable for unigrams.              Default is None
        Output: List of List of Strings.
        Note: will automatically change to lowercase, and will automatically lemmatize.
    '''
    if ngram == 1 and (pos_tagset == None or pos_tagset == "universal"): ## Will perform POS-tagging
        return [nltk.pos_tag(split_message_into_tokens(untokenized_message, ngram = ngram, stopwords = stopwords, regex_string = regex_string, handle_negations = handle_negations), pos_tagset = pos_tagset) for untokenized_message in message_list]
    else:
        return [split_message_into_tokens(untokenized_message, ngram = ngram, stopwords = stopwords, regex_string = regex_string, handle_negations = handle_negations) for untokenized_message in message_list]

# %%
## STEP 1: PREPROCESSING
df = pd.read_csv(FILENAME, delimiter = ',')
faulty_arrays = []
good_arrays = []

for i in range(len(df[[COLUMN_NAME]].values.tolist())):
    message = df[COLUMN_NAME].values.tolist()[i]
    if not is_ASCII_string(ascii_substituted(str(message))):
        faulty_arrays.append(i)
    else:
        df.set_value(i, COLUMN_NAME, ascii_substituted(str(message)))
        good_arrays.append(i)
        
df = df.iloc[good_arrays, :]

# %%
msg_list = get_message_list(df)
t = time.time()
# do stuff
tokenz = tokenize(msg_list)
print (time.time() - t)
tokenz
# Out:
# 1.81709384918
# [['good', 'information'],
#  [u'feel', 'like', 'ad', 'credit', u'card', 'mentioned'],
#  ['account',
#   'manager',
#   'american',
#   'express',
#   'not_explain',
#   'closed',
#   'account',
#   'pending',
#   'balance',
#   'what',
#   'happen',
#   u'point',
#   'earned',
#   '?'],
#  ['american',
#   'express',
#   'allowed',
#   'carry',
#   '14,000',
#   'balance',
#   'accrued',
#   'interest',
#   'late',
#   'jacked',
#   '29.9',
#   'one',
#   u'way',
#   'paying',
#   'transfer',
#   '6500',
#   'new',
#   '0',
#   'apr',
#   'card',
#   'maxed',
#   'new',
#   'credit',
#   'line',
#   '6500',
#   'part',
#   'pay',
#   'year',
#   'plan',
#   'getting',
#   'rid',
#   'amex',
#   'debt',
#   'first',
#   'paying',
#   'new',
#   'card',
#   '0',
#   'apr',
#   'promotion',
#   u'end',
#   'however',
#   'concerned',
#   'maxed',
#   'available',
#   'credit',
#   'hurting',
#   'credit',
#   'score',
#   'amex',
#   'never',
#   'gave',
#   'limit',
#   'let',
#   'pay',
#   'time',
#   'know',
#   'answer',
#   'please',
#   'email',
#   'jsagewalker',
#   'gmail.com'],
#  [],
#  [],
#  ['gave', 'rec', 'card', 'considering'],
#  ['american', 'express', 'best'],
#  ['not_well', 'least', "not_'s", 'excellent'],
#  ['made', 'not_sense', 'wasted', 'time', 'buddy'],
#  ['what', 'date', 'invented', '?'],
#  ['evrtyytjrklgnjlskdgh'],
#  ['thank',
#   'credit',
#   'score',
#   'low',
#   'money',
#   'tight',
#   'feeling',
#   'little',
#   'desperate',
#   'googled',
#   'away',
#   'came',
#   'across',
#   'netfirst',
#   'platnum',
#   'glad',
#   'nerd',
#   'wallet',
#   'people',
#   'like'],
#  [u'company', 'ridiculous', 'refund', 'tell', 'get', 'lost'],
#  ['information', 'not_date'],
#  ['not_information',
#   'helpful',
#   'almost',
#   'applied',
#   'horizon',
#   'gold',
#   'thanks',
#   'much'],
#  ['grateful',
#   'knowledge',
#   'going',
#   'apply',
#   'horizon',
#   'gold',
#   'credit',
#   'card',
#   'appreciative',
#   'blog'],
#  ['keep', 'information', 'coming'],
#  ['helpful'],
#  ['bcp'],
#  ['what', 'bank', u'sponsor', 'elan', '?'],
#  ['not_enough', 'detail', 'elan', 'company'],
#  ['elan',
#   u'u',
#   'bank',
#   '?',
#   'talking',
#   'someone',
#   'overseas',
#   'issue',
#   'issue',
#   'arises',
#   'saturday',
#   'wait',
#   'monday',
#   'get',
#   'resolved',
#   '?'],
#  ['great', 'explanation'],
#  ['fruadgelent',
#   'activity',
#   'card',
#   'canceled',
#   'recieved',
#   'income',
#   'tax',
#   u'return',
#   'another',
#   'card',
#   'issused',
#   'sent',
#   'address',
#   'never',
#   'heard',
#   'yuba',
#   'city',
#   'current',
#   'address',
#   '42',
#   'collegee',
#   'woodland',
#   'ca',
#   '95696',
#   'reported',
#   'activity',
#   'on4',
#   '21',
#   '16',
#   'account',
#   'faxed',
#   'information',
#   'requested',
#   'account',
#   'card',
#   'ending',
#   '5127',
#   'possision',
#   'would',
#   'like',
#   'release',
#   'money',
#   'card'],
#  ['thank',
#   'much',
#   'writing',
#   'warning',
#   'accoutnow',
#   'almost',
#   'signed',
#   'gold',
#   'card',
#   'looked',
#   u'review',
#   'google',
#   'read',
#   'article',
#   'thank',
#   'saving',
#   'hard-earned',
#   'cash',
#   'stolen'],
#  ['not_like', 'eat', 'ur', 'money', 'u', 'earned', 'think', 'going', 'leave'],
#  ['im',
#   'telling',
#   'everybody',
#   'account',
#   'card',
#   'dont',
#   'use',
#   'cause',
#   'not_worth',
#   'real'],
#  ['not_accurate',
#   'lot',
#   u'fact',
#   'wrong',
#   u'fee',
#   'charged',
#   '5',
#   'per',
#   'month',
#   'plan',
#   'when',
#   'direct',
#   u'deposit',
#   'payroll',
#   'not_fees',
#   u'purchase',
#   u'transaction',
#   'when',
#   'using',
#   u'atm',
#   'gas',
#   u'pump',
#   'direct',
#   u'deposit',
#   'payroll',
#   u'account',
#   u'get',
#   'posted',
#   'two',
#   u'day',
#   'earlier',
#   'netspend',
#   'account',
#   'versus',
#   'traditional',
#   'bank',
#   u'hold',
#   'direct',
#   'deposit',
#   '2',
#   u'day',
#   'letting',
#   'access',
#   u'fund',
#   'people',
#   'bad',
#   'credit',
#   'ca',
#   'not_get',
#   'credit',
#   u'card',
#   'ever',
#   'tried',
#   'apply',
#   'credit',
#   'card',
#   'when',
#   'bad',
#   'credit',
#   '?',
#   'credit',
#   u'go',
#   'south',
#   'not_traditional',
#   'bank',
#   u'want',
#   'give',
#   'loan',
#   'extend',
#   'credit',
#   'period',
#   'research'],
#  ['purchase', 'how', 'activate', '?'],
#  ['would',
#   'love',
#   'look',
#   'egifter.com',
#   'handle',
#   'technology',
#   u'company',
#   'like',
#   'target',
#   'william',
#   'sonoma',
#   'consumer',
#   'side',
#   'sell',
#   '250',
#   u'card',
#   u'point',
#   'reward',
#   'system',
#   'include',
#   'group',
#   'gifting'],
#  ['verry', 'helpful'],
#  ['never',
#   'stated',
#   'whats',
#   'good',
#   'credit',
#   'score',
#   'apply',
#   'what',
#   'card'],
#  ['not_tell',
#   'how',
#   'apply',
#   'talking',
#   'already',
#   'credit',
#   'what',
#   'not_?',
#   'not_helpful'],
#  ['would',
#   'nice',
#   'offer',
#   'credit',
#   'score',
#   'scenario',
#   'help',
#   u'customer',
#   'determining',
#   'right',
#   'card',
#   'apply',
#   'well'],
#  ['generic', 'bullshit'],
#  ['thanks'],
#  ['not_tell', 'how', 'get', 'credit', 'card'],
#  ['score',
#   'low',
#   'what',
#   u'chance',
#   'getting',
#   '1000',
#   'dollar',
#   'limit',
#   '500',
#   '?'],
#  ['nice', 'article', 'le'],
#  ['stupid', 'not_give', 'advice', 'already', 'common', 'sense'],
#  ['credit',
#   '700',
#   'what',
#   'credit',
#   'card',
#   'would',
#   'good',
#   '2',
#   'apply',
#   '?',
#   'thank'],
#  ['not_useful', 'info'],
#  ['boring'],
#  ['not_see', 'free', 'credit', 'card', '300', 'credit', 'limit'],
#  ['not_help', 'apply', 'one', u'tell', 'what'],
#  [],
#  ['how', 'get', 'credit', 'card', 'never', 'one', '?'],
#  ['jkdtgd'],
#  ['not_time'],
#  [],
#  [],
#  [],
#  [],
#  ['not_time', 'thank'],
#  ['thanks', 'info'],
#  ['wack'],
#  ['exactly', 'what', 'needed', 'read', 'thank'],
#  ['thank', 'much'],
#  ['really', u'want', 'try', 'c', 'get', 'approved', 'dis', 'card'],
#  ['gave', 'idea', 'when', 'apply', 'another', 'card'],
#  ['thanks', 'help'],
#  ['fag'],
#  [],
#  ['peace', 'shit'],
#  ['kiss', 'dick', 'hahaha', 'jk'],
#  ['thank', 'ya', 'much'],
#  ['want', 'rebuild', 'credit'],
#  ['tell', 'something', "don'tknow"],
#  ['yes'],
#  ['everything'],
#  ['not_where', 'start', '?'],
#  ['thanks', 'article', 'helpful'],
#  ['not_new', 'information'],
#  ['light', 'detail'],
#  ['not_give', 'god', u'suggestion', 'cc', 'high', u'limit', 'bad', 'credit'],
#  ['not_enough', u'detail'],
#  ['google',
#   'need',
#   'cell',
#   'home',
#   'phone',
#   'number',
#   'apply',
#   'credit',
#   'denied',
#   'use',
#   u'parent',
#   'number',
#   'since',
#   'live',
#   'home',
#   'share',
#   'dress'],
#  ['common', 'sense'],
#  ['what', 'number'],
#  ['not_credit', 'catds', 'bad', 'credit', 'information'],
#  ['great', 'information'],
#  ['not_facebook'],
#  ['nice'],
#  ['not_credit', 'still', 'apply'],
#  ['none', 'thanks'],
#  ['bit',
#   'harsh',
#   'least',
#   'attempt',
#   'level',
#   'playing',
#   'field',
#   'not_options',
#   'yes',
#   u'fee',
#   'seem',
#   'extreme',
#   'sure',
#   'big',
#   'fail',
#   u'bank',
#   'involved',
#   'setting',
#   u'fee',
#   'since',
#   'debit',
#   'prepaid',
#   u'card',
#   'go',
#   'eventually',
#   'go',
#   'network',
#   'order',
#   'work'],
#  ['thanks', 'comparing'],
#  ['not_answer', 'anything', 'tbh'],
#  ['why',
#   'not_give',
#   u'u',
#   'list',
#   u'bank',
#   'who',
#   'offer',
#   'teen',
#   'banking',
#   'program',
#   '?'],
#  ['not_list', 'best', 'breed', 'teen-ready', u'bank'],
#  ['need', u'bank', 'cover', 'many', u'area', 'u.s'],
#  ['not_banks', 'state'],
#  ['where', 'get', 'card'],
#  [],
#  ['plenty',
#   'mail',
#   u'offer',
#   'lucrative',
#   'received',
#   'offer',
#   'amex',
#   'platinum',
#   '100,000',
#   u'point',
#   'bonus',
#   'received',
#   'plenty',
#   'great',
#   'snail',
#   'mail',
#   u'offer'],
#  ['want', 'find', 'local', 'participating', 'bank'],
#  ['really', 'like', 'how', 'detailed', u'reward', u'difference', 'card'],
#  ['need', 'info'],
#  ['keep', 'goodwork', 'home', 'slice'],
#  ['not_information',
#   'actual',
#   u'fee',
#   'know',
#   'western',
#   'union',
#   'expensive',
#   'transfer',
#   'money',
#   'not_know',
#   'how',
#   u'alternative',
#   'compare'],
#  ['looking',
#   'second',
#   'method',
#   'go',
#   'check',
#   'cash',
#   'one',
#   'method',
#   u'cashier',
#   'check',
#   'trying',
#   'think',
#   'older',
#   'method',
#   'well',
#   'bit',
#   'behind',
#   'time',
#   'afraid'],
#  ['bitcoin', 'way', 'send', 'money', 'individual'],
#  ['great',
#   'review',
#   'sure',
#   'what',
#   'think',
#   'ppl',
#   'looking',
#   'article',
#   'what',
#   'populates',
#   'google',
#   'search',
#   'cheapest',
#   'credit',
#   'card',
#   'payment',
#   u'option',
#   'via',
#   'web',
#   'phone',
#   'app',
#   'great',
#   'bank',
#   u'transfer',
#   'credit',
#   u'card',
#   'zero',
#   'near-zero',
#   u'fee',
#   'would',
#   'mind-blowing',
#   'thanks'],
#  ['quest',
#   'asked',
#   'how',
#   'send',
#   'money',
#   'account',
#   'using',
#   'credit',
#   'card'],
#  ['thank',
#   'needed',
#   'app',
#   'would',
#   'send',
#   'money',
#   'bank',
#   'account',
#   'helped',
#   'find',
#   'quickly'],
#  ['sending',
#   'money',
#   'free',
#   'must',
#   'bank',
#   u'offer',
#   'account',
#   'where',
#   'send',
#   'money'],
#  ['not_enough',
#   u'option',
#   'also',
#   'chart',
#   'compare',
#   u'feature',
#   'giving',
#   'two',
#   u'option',
#   'hardly',
#   'list'],
#  [u'bank', 'child', 'enter', 'not_online'],
#  ['thanks', 'depth', 'information', 'informative'],
#  [],
#  ['not_say',
#   'two',
#   'biggest',
#   u'bank',
#   'offer',
#   'senior',
#   u'discount',
#   'could',
#   'continue',
#   'research'],
#  ['thank', 'speaking/writing', 'people', 'dignified', 'way'],
#  ['good', '411'],
#  ['old'],
#  ['info', 'always', 'plus'],
#  ['wanted', 'list', 'grocery', u'store', 'accept', 'american', 'express'],
#  ['what',
#   'pro',
#   'con',
#   'money',
#   'market',
#   'account',
#   'how',
#   'much',
#   'money',
#   'start',
#   'deposit',
#   '?',
#   '?'],
#  ['not_example',
#   'how',
#   'money',
#   'market',
#   'account',
#   'work',
#   'give',
#   'scenario'],
#  ['question', 'what', 'federal', 'money', 'market', 'account', '?'],
#  ['not_give', 'info', 'looking'],
#  ['efficient', 'good', 'information', 'compact', u'fact'],
#  ['thank', 'theinfo'],
#  ['old'],
#  ['where',
#   'apply',
#   'insurance',
#   u'employee',
#   'small',
#   'restaurant',
#   'oklahoma',
#   'would',
#   'insurance',
#   u'employee'],
#  ['quality', 'review', 'needed', 'service', 'reduction', 'etc'],
#  ['not_actually', 'read', 'lol'],
#  ['need', u'bank'],
#  ['think',
#   'capital',
#   'one',
#   '360',
#   'make',
#   'logo',
#   'snazzier',
#   'like',
#   'orange',
#   'ball'],
#  ['crappy', 'article'],
#  ['defenitly',
#   'going',
#   'stop',
#   'capital',
#   'one',
#   'today',
#   'open',
#   '360',
#   'account'],
#  ['img', 'acct', 'lost', 'info', 'need', 'contact', 'number'],
#  ['made',
#   'check',
#   'person',
#   'decided',
#   'not_sell',
#   'item',
#   'already',
#   'made',
#   'name',
#   'how',
#   'cancel',
#   'money',
#   'put',
#   'back',
#   'account'],
#  ['many',
#   'pre',
#   'paid',
#   'card',
#   u'year',
#   'unbankable',
#   'bluebird',
#   'best',
#   'thing',
#   'happen',
#   'pre',
#   'paid',
#   u'card',
#   'ever',
#   'huge',
#   'thank'],
#  ['information', 'seems', 'clash', u'site', '2013'],
#  ['create', 'business', 'change', 'business', 'dose'],
#  ['guess', 'mortgage', 'wait'],
#  ['would', u'mouse', 'include', 'crime', 'information'],
#  ['need', 'land', 'median'],
#  [u'guy', 'great'],
#  ['never', 'told', u'u', u'name', u'lender', 'give', 'bcc', 'not_pg'],
#  ['thsnk', 'much', 'best', u'girl', 'god', 'bless'],
#  ['car',
#   'repair',
#   'generally',
#   'considered',
#   'appropriate',
#   'use',
#   'emergency',
#   u'fund'],
#  ['how', 'get', 'personal', 'loan', u'guy'],
#  ['car', 'repair', 'emergency', 'form', 'transportation', 'work'],
#  ['0', 'income', 'become', 'disabled', 'lot', u'bill', 'pay.what', '?'],
#  ['lost', 'car', 'need', 'money'],
#  [u'number', u'lie', 'lived', u'town', 'information', 'article', 'incorrect'],
#  ['great', 'article'],
#  [u'link', 'real', 'estate', u'site', 'would', 'great'],
#  [],
#  ['need', 'borrow', '300', u'dollar', 'yesterday'],
#  ['looking',
#   'alternative',
#   'non',
#   'credit',
#   'solution',
#   'similar',
#   'payday',
#   'loan'],
#  ['informative'],
#  ['johndavid71', 'naij.com', 'precious123'],
#  ['please',
#   'describe',
#   'greater',
#   'detail',
#   'how',
#   'open',
#   u'saving',
#   'account',
#   '?',
#   'what',
#   'difference',
#   'checking',
#   'saving',
#   'etc',
#   u'account',
#   '?'],
#  ['love', 'love', 'love', 'nerd', 'wallet', 'go'],
#  ['understand',
#   'what',
#   'saying',
#   'daughter',
#   '1',
#   'want',
#   'make',
#   'sure',
#   'set',
#   'life'],
#  ['not_recommend', 'ay', 'bank'],
#  ['not_say', 'what', 'supposed'],
#  [],
#  ['how', 'much', 'open', 'child', 'account', 'deposit', 'month', '?'],
#  ['gave', 'info', 'needed', 'make', 'good', 'choice', 'thanks'],
#  ['not_enough', 'info'],
#  ['one', 'sided', 'extreme', 'use', u'case'],
#  ['not_answer', 'answer'],
#  [],
#  ['wheres', 'work', 'sheet', 'need', '?'],
#  ['need', 'know', 'what', 'maximum', 'amount'],
#  ['useful'],
#  ['illustrate', 'bill', u'figure', 'would', 'easy', 'understand'],
#  ['thanks', 'making', 'people', 'aware', 'read', 'fine', 'print'],
#  ['yes',
#   'find',
#   'article',
#   'helpful',
#   'information',
#   'not_know',
#   'credit',
#   'card',
#   'why',
#   'not_one',
#   'feedback',
#   'iff',
#   'know',
#   'not_afford',
#   'credit',
#   'card',
#   'not_purchase',
#   'one',
#   'people',
#   'sometime',
#   'get',
#   'credit',
#   u'card',
#   'one',
#   'abusing',
#   'severely',
#   'please',
#   'stop',
#   'know',
#   'not_mature',
#   'enough',
#   'handle',
#   'not_realize',
#   u'hurt',
#   'credit',
#   'score',
#   'when',
#   'not_make',
#   'minimum',
#   'payment',
#   'time'],
#  ['not_answer', 'question'],
#  ['thanks', 'helpful'],
#  ['u', 'suck'],
#  ['wordy'],
#  ['sdfghjkl'],
#  ['pay', 'whole', 'amount', 'back', 'card', 'reloads'],
#  ['informative', u'thing', 'not_know', 'careful', 'credit', 'card'],
#  ['needed', 'project', 'helped', 'little', 'thanks'],
#  ['add',
#   'section',
#   'result',
#   'where',
#   'stop',
#   'charging',
#   u'card',
#   'keep',
#   'paying',
#   'minimum',
#   'payment',
#   'clear',
#   'debt',
#   'particular',
#   'card'],
#  ['helped',
#   'understand',
#   'pay',
#   'least',
#   'worry',
#   'credit',
#   'score',
#   'dropping'],
#  ['thanks', u'help', 'alot'],
#  [],
#  ['kept',
#   'scaring',
#   'crap',
#   'could',
#   'said',
#   'nice',
#   u'thing',
#   'least',
#   'said',
#   'harsh',
#   u'thing',
#   'nice',
#   'way',
#   'jeez'],
#  ['said', 'what', 'not_what', 'alternative'],
#  ['how',
#   'get',
#   'money',
#   'card',
#   'how',
#   'make',
#   'atm',
#   'card',
#   'cause',
#   'pay',
#   'rent',
#   'not_take',
#   'card'],
#  ['great',
#   'info',
#   'ceo',
#   'steven',
#   'craig',
#   'shopnick',
#   'american',
#   'express',
#   'best',
#   'credit',
#   'card',
#   'world'],
#  ['way', 'make', 'best', 'offer'],
#  [],
#  ['asking', 'how', 'much', 'money', 'card', 'hold'],
#  ['v'],
#  ['why', 'american', 'express', 'serve', 'dose', 'not_work', u'country', '?'],
#  ['not_explain', 'depth', 'amex', 'serve'],
#  ['nope'],
#  ['not_allude', u'dealer', 'know', 'discount', 'increase', 'sale', 'price'],
#  ['not_help',
#   'cause',
#   'dum',
#   'not_ofense',
#   'sorry',
#   'grammer',
#   'im',
#   'lazy',
#   'today',
#   'fix',
#   'die',
#   'jk',
#   'lol',
#   'well',
#   'please',
#   'improve'],
#  ['where', 'rest', u'result', '?', 'see', '10'],
#  [],
#  ['improve', 'calculating', u'sale', u'tax', 'tweak', u'result'],
#  ['wa',
#   'odd',
#   u'spirit',
#   u'tax',
#   'per',
#   'bottle',
#   'plus',
#   u'tax',
#   'total',
#   'probably',
#   '41.3'],
#  ['personal', 'unsecured', u'loan', 'help', 'fico', 'score', '?'],
#  ['how',
#   'many',
#   u'account',
#   'many',
#   'seems',
#   'like',
#   'reasonable',
#   'question',
#   'article',
#   'not_nearly',
#   'specific',
#   'enough'],
#  ['thank'],
#  ['told',
#   'quit',
#   'getting',
#   u'card',
#   u'store',
#   'regularly',
#   'shop',
#   u'make',
#   'credit',
#   'revolving',
#   'not_want',
#   'get',
#   'regular',
#   'credit',
#   'card',
#   'usually',
#   'pay',
#   'cash',
#   u'place',
#   'wrong',
#   '?'],
#  ['much', 'vague'],
#  ["not_n't", 'need', 'final'],
#  ['wife',
#   'died',
#   'march',
#   '1,2016.',
#   u'well',
#   'fargo',
#   'informed',
#   'within',
#   u'day',
#   'death',
#   'say',
#   'co-signer',
#   'card',
#   'never',
#   'signed',
#   'anthing',
#   'account',
#   'changed',
#   'name',
#   'new',
#   'account',
#   'number',
#   'told',
#   'stop',
#   'account',
#   'would',
#   'not_pay',
#   'anything',
#   'what',
#   'live',
#   'colorado',
#   u'well',
#   'fargo',
#   'take',
#   'money',
#   u'well',
#   'fargo',
#   'checking',
#   'account',
#   '?',
#   'attach',
#   'social',
#   'security',
#   'disability',
#   'account',
#   'put',
#   'lean',
#   'mortgaged',
#   'house',
#   '?'],
#  ['option', 'son', 'fails', 'qualify', 'credit', 'card', 'college'],
#  ['excellent'],
#  ['relocating',
#   'ohio',
#   'colorado',
#   'madyer',
#   'education',
#   '35',
#   u'yr',
#   'teaching',
#   '3',
#   u'year',
#   'teaching',
#   'college',
#   'level',
#   u'course',
#   'employable',
#   'university',
#   'level',
#   '?'],
#  ['oxford',
#   'one',
#   'highest',
#   'top',
#   '10',
#   'one',
#   'fastest',
#   'growing',
#   u'city',
#   u'u',
#   'great',
#   'school',
#   'system',
#   'crazy',
#   '?'],
#  ['4',
#   'provide',
#   'information',
#   'how',
#   'find',
#   'good',
#   'consolidation',
#   u'service',
#   'otherwise',
#   'great',
#   'article'],
#  ['how', 'long', 'take', 'pay', '15000', '9.74', 'interest'],
#  ['person',
#   'credit',
#   'card',
#   'please',
#   'not_use',
#   'unless',
#   'pay',
#   'amount',
#   'when',
#   'get',
#   'statement',
#   'not_good',
#   'feeling',
#   'when',
#   'not_pay',
#   'debt',
#   u'make',
#   'feel',
#   'sick',
#   'inside',
#   'use',
#   'card',
#   'when',
#   'absolutely',
#   'necessary'],
#  ['thanks'],
#  ['want', 'know', 'how', 'much', 'interest', 'pay', 'monthly', 'balance'],
#  ['asked', 'what', 'would', u'payment', '15,000.00'],
#  ['thanks',
#   'information',
#   'friend',
#   'mine',
#   'bank',
#   'account',
#   'compromised',
#   'without',
#   'atm',
#   'card',
#   u'thief',
#   'getting',
#   'slick',
#   'second',
#   'better',
#   'security',
#   'bank',
#   u'account',
#   'how',
#   'people',
#   'survive',
#   u'threat',
#   'chip',
#   'card',
#   'joke',
#   'police',
#   u'need',
#   'step',
#   'game',
#   'pure',
#   'bull',
#   'how',
#   'feed',
#   u'child',
#   'next',
#   '48',
#   u'hour',
#   'wrong',
#   'money',
#   'put',
#   'back',
#   'talk',
#   u'customer',
#   'service',
#   'pnc',
#   u'bank',
#   'bank',
#   u'minute',
#   'not_write',
#   'anyway',
#   'thank',
#   'nerd',
#   'wallet'],
#  ['yeeeeee'],
#  ['originality'],
#  ['helped'],
#  ['thank', 'helping', 'get', 'credit', 'back', 'where'],
#  ['not_debt',
#   'income',
#   'credit',
#   u'card',
#   'high',
#   'debt',
#   'income',
#   'student',
#   u'loan',
#   'medical',
#   'school'],
#  ['what',
#   u'asset',
#   'particularly',
#   'liquid',
#   u'asset',
#   'stupid',
#   'cc',
#   u'company',
#   'not_really',
#   'seem',
#   'understand',
#   'finance',
#   'funny',
#   'considering',
#   'business'],
#  ['cutting', 'not_work'],
#  ['thanks'],
#  ['trying',
#   'find',
#   'got',
#   'home',
#   'depot',
#   'credit',
#   'card',
#   'how',
#   'long',
#   'would',
#   'take',
#   'canceled',
#   'due',
#   'inactivity'],
#  ['not_actually', 'what', 'looking', 'informative'],
#  ['great', 'advice', 'definetely', 'use', 'advantage'],
#  ['how', 'long', 'must', 'inactive', 'canceled'],
#  ['retired',
#   'z',
#   'got',
#   '2',
#   u'month',
#   'inactive',
#   'card',
#   'cancelled',
#   'lesser',
#   'impact',
#   'close',
#   'got',
#   'inactive',
#   'card',
#   'cancellation',
#   'closed',
#   '2',
#   u'month',
#   'lesser',
#   'different',
#   'score',
#   'impact',
#   'close',
#   'account',
#   'issuer',
#   '?',
#   'close',
#   'account',
#   'manner',
#   u'minute',
#   'not_need',
#   'wait',
#   'language',
#   'pretty',
#   'clear',
#   'use',
#   'card',
#   'gone',
#   'paying',
#   'full',
#   'month',
#   'auto',
#   'pay',
#   'not_supposed',
#   'slap',
#   'wrist',
#   'appreciate',
#   'advice',
#   'burned',
#   'twice',
#   'learned'],
#  ['information',
#   'conflicting',
#   'information',
#   'credit',
#   u'card',
#   'another',
#   'site',
#   'said',
#   'credit',
#   'score',
#   u'get',
#   'dinged',
#   'cancellation',
#   'default',
#   'delinquency',
#   'also',
#   u'say',
#   'pay',
#   'balance',
#   'full',
#   'month',
#   'credit',
#   'card',
#   u'company',
#   'making',
#   'not_interest',
#   u'company',
#   'like',
#   'see',
#   'people',
#   'making',
#   'monthly',
#   u'payment',
#   'revolving',
#   'credit'],
#  [],
#  ['practice', 'unfair'],
#  [u'say', 'use', 'card'],
#  ['military',
#   u'member',
#   'receive',
#   '30',
#   u'day',
#   'leave',
#   'per',
#   'year',
#   'however',
#   'unlike',
#   'civilian',
#   'personnel',
#   'take',
#   'leave',
#   'travel',
#   'certain',
#   'distance',
#   'away',
#   'home',
#   'base',
#   u'weekend',
#   'example',
#   '3',
#   'day',
#   'holiday',
#   'weekend',
#   'like',
#   'memorial',
#   'day',
#   'service',
#   'member',
#   'must',
#   'use',
#   '3',
#   u'day',
#   'leave',
#   'travel',
#   'somewhere',
#   'away',
#   'base',
#   'sat-mon',
#   'thought',
#   'helpful',
#   'putting',
#   '30',
#   u'day',
#   'leave',
#   'perspective',
#   'thanks',
#   'great',
#   'article'],
#  ['shitty', 'info'],
#  ['completely', 'inaccurate'],
#  ['nay'],
#  ['not_tell', u'place', 'not_take', 'big', 'unconvince', 'when'],
#  ['how', 'many', u'merchant', '?'],
#  [],
#  ['got', 'info', 'needed'],
#  [],
#  ['nope'],
#  [],
#  ['experience',
#   'amex',
#   'card',
#   'four',
#   'experience',
#   'set',
#   'back',
#   'ccompanies',
#   'not_accept',
#   'amex',
#   u'card',
#   'overall',
#   'use',
#   'amex',
#   'card',
#   'every',
#   'where',
#   'like',
#   'article',
#   'stated',
#   'wewealthiest',
#   u'customer',
#   'like',
#   'shop',
#   'amex',
#   u'card',
#   'not_one',
#   'middle',
#   'class',
#   'like',
#   'earn',
#   u'perk',
#   u'reward',
#   'point',
#   'amex',
#   u'offer',
#   'amex',
#   'also',
#   'best',
#   'customer',
#   'service',
#   'money',
#   'buy'],
#  ['not_good',
#   'answer',
#   'why',
#   'amex',
#   'not_accepted',
#   'frequently',
#   'apperciated',
#   'ur',
#   'unbiased',
#   'opion'],
#  ['wanted', 'know', 'where', 'american', 'express', 'accepted'],
#  ['thank'],
#  ['brief', 'concise', 'thanks'],
#  ['awesome',
#   'trying',
#   'figure',
#   'why',
#   '?',
#   'however',
#   'reading',
#   'article',
#   'everything',
#   'make',
#   'sence',
#   'thank',
#   'much'],
#  [],
#  ['good', 'article'],
#  ['would',
#   'love',
#   'one',
#   'clientele',
#   u'travel',
#   'world',
#   u'get',
#   'use',
#   'classy',
#   'privileged',
#   'flyer',
#   u'lounge',
#   'oh',
#   'well',
#   'still',
#   'use',
#   'little',
#   'business',
#   'costco',
#   'amex',
#   'card',
#   'whenever',
#   'great',
#   'customer',
#   'service',
#   'well',
#   'worth'],
#  ['great',
#   'article',
#   'clearly',
#   'explained',
#   'short',
#   'why',
#   u'business',
#   'not_accept',
#   'american',
#   'express',
#   'credit',
#   u'card',
#   'thanks',
#   'share',
#   'others',
#   'issue',
#   'arises'],
#  ['tim', 'cancel', 'card'],
#  ['churning', u'rock'],
#  ['helpful', 'awesome', 'overview'],
#  ['not_specific', 'info', 'car', 'rental', 'insurance', 'coverage'],
#  [],
#  ['thanks', 'fa'],
#  ['excellent', 'educative'],
#  ['list', u'example', 'what', 'bad', 'credit', 'score', 'would'],
#  ['thank',
#   'article.it',
#   'informative',
#   'inspiring.patience',
#   'really',
#   'virtue'],
#  [],
#  ['thanks',
#   'hint',
#   'special',
#   'circumstances.it',
#   'also',
#   u'help',
#   'people',
#   'trying',
#   'increase',
#   'score',
#   'short',
#   'amount',
#   'time',
#   u'take',
#   'discipline',
#   'discipline'],
#  [u'give', 'many', u'thing', 'consider', 'great', 'thank'],
#  ['one',
#   'month',
#   'ago',
#   'got',
#   'store',
#   'credit',
#   'card',
#   'how',
#   'long',
#   'wait',
#   'apply',
#   'amex',
#   'card',
#   'credit',
#   'score',
#   'good'],
#  ['how', 'long', 'person', 'wait', 'applying', '?'],
#  ['not_apply', u'student', 'who', 'applied', 'first', 'credit', 'card'],
#  ['not_moment'],
#  [],
#  ['interesting', 'concept'],
#  ['okay'],
#  ['not_answer', 'question'],
#  [u'source', 'secure', 'credit', u'card'],
#  ['thankx', u'guy'],
#  ['worried', u'hacker'],
#  ['thank', 'helping', 'feel', 'safer'],
#  ['thanks'],
#  ['nothing',
#   'much',
#   'wrong',
#   'obvious',
#   'follow',
#   'rarely',
#   'shop',
#   'online',
#   'when',
#   'use',
#   'paypal',
#   'yet',
#   'someone',
#   'draned',
#   'bank',
#   'acct',
#   'florida',
#   'where',
#   'never',
#   'live',
#   'pa.',
#   'how',
#   'possible',
#   'addition',
#   'shopping',
#   'online',
#   'managed',
#   'buy',
#   'taco',
#   'bell',
#   'card',
#   'possession',
#   '?'],
#  ['amazing', 'great', 'information'],
#  ['great', 'information', 'look', 'somewhere', 'situation'],
#  ['helpful', 'blog', 'thank', 'much', 'please', 'keep', 'writing'],
#  ['looking',
#   'how',
#   'transaction',
#   'routed',
#   'issuer',
#   'bank',
#   'how',
#   'settlement',
#   'made',
#   'book',
#   u'entry'],
#  ['thanks'],
#  ['yes', 'great', 'saved', 'headache', 'pocket', u'pain', 'well', 'thanks'],
#  ['gave',
#   'limited',
#   'amount',
#   'cash',
#   'get',
#   'why',
#   'come',
#   'credit',
#   'line',
#   'amount'],
#  ['not_show', 'how', 'take', 'advance', 'withdrawal', u'credit', 'card'],
#  ['bullshit'],
#  ['cash',
#   'advance',
#   'not_defined',
#   'what',
#   'want',
#   'cash',
#   'back',
#   'purchase',
#   '?'],
#  ['late', 'nice', u'option'],
#  ['not_bank', 'number'],
#  ['not_english', u'bank'],
#  ['need', 'phone', 'number', 'call', 'make', 'report'],
#  ['detailed', 'helpful', 'thank', 'much'],
#  ['not_give', u'answer', 'needed', 'failed'],
#  ['hold', '2', 'credit', u'card', 'case', 'one', u'get', 'lost'],
#  ['helpful'],
#  ['trash'],
#  ['many', u'answer'],
#  [],
#  [],
#  ['ree'],
#  ['faadgfsafgf'],
#  ['context'],
#  ['not_real', u'detail'],
#  ['helpful', 'made', 'better', 'idea', 'credit', 'card', 'increase'],
#  [],
#  ['terrible', 'overall', 'advice'],
#  ['article',
#   'not_clear',
#   'difference',
#   'paying',
#   'car',
#   'credit',
#   'card',
#   'transferring',
#   'balance',
#   'credit',
#   'card',
#   'personal',
#   'inquiry',
#   'whether',
#   'pay',
#   'card',
#   'thereby',
#   'reaping',
#   'significant',
#   u'reward',
#   'subsequently',
#   'pay',
#   'card',
#   'full',
#   'article',
#   'not_address',
#   'option',
#   'let',
#   'know',
#   'whether',
#   'option'],
#  ['stupid'],
#  ['lost',
#   'job',
#   u'mean',
#   'dont',
#   'money',
#   'pay',
#   'how',
#   'lerson',
#   'lost',
#   'job',
#   'thinking',
#   'abkut',
#   'foing',
#   'mall',
#   'thats',
#   'crazy'],
#  ['not_new', 'information'],
#  ['debt',
#   'addressed',
#   'first',
#   'spender',
#   'who',
#   'debt',
#   'not_use',
#   'card',
#   'how',
#   u'parent',
#   'managed',
#   'stay',
#   'debt',
#   'temptation',
#   'free',
#   u'mile',
#   'paying',
#   u'month',
#   'interest',
#   'warning',
#   'link',
#   'top',
#   'article',
#   'teach',
#   'who',
#   'steer',
#   'clear',
#   'credit',
#   'card',
#   'spending',
#   'i.e.',
#   'anyone',
#   'credit',
#   'card',
#   'debt',
#   'article',
#   u'hurt',
#   'people',
#   'who',
#   'not_know',
#   'better'],
#  ['thank', 'web', 'site', 'helpful'],
#  ['not_tell', 'what', 'airline', 'speaks', 'general', u'term'],
#  ['keep', 'good', 'work'],
#  ['wonderful',
#   'report',
#   'thank',
#   'apply',
#   'good',
#   'spending',
#   u'habit',
#   'david',
#   'dante'],
#  ['awesome', 'useful'],
#  ['redondo', 'beach', 'not_cheap'],
#  ['thank'],
#  ['not_cities', 'listed'],
#  ['none', u'number', 'currently', 'working'],
#  ['thanks'],
#  ['keep', 'god', 'work'],
#  [],
#  ['also', 'think', 'beginning', 'cost', 'annually'],
#  ['whoda', 'thunk', '?', 'thanks'],
#  ['interesting'],
#  ['card', 'concidered', 'first', 'credit', 'vard'],
#  ['thank'],
#  [u'tip', 'still', 'require', 'credit', 'card', 'check', 'credit'],
#  ['not_list', 'rental', 'car', u'place'],
#  ['thanks',
#   'sharing',
#   'useful',
#   'information',
#   'every',
#   'community',
#   u'need',
#   'economically',
#   'sound',
#   'strong',
#   u'bank',
#   'service',
#   u'need',
#   'people',
#   u'make',
#   'happen'],
#  ['thank', 'jump', u'link'],
#  ['need',
#   u'article',
#   'black',
#   u'bank',
#   'would',
#   'like',
#   'know',
#   'how',
#   'black',
#   u'bank',
#   'market',
#   'aggressive',
#   'reaching',
#   u'folk',
#   'black',
#   u'church',
#   u'business',
#   '?'],
#  ['thank', 'much'],
#  ['thank'],
#  ['yes', 'apply', u'loan'],
#  [u'balance',
#   u'card',
#   'name',
#   '?',
#   'credit',
#   u'card',
#   u'husband',
#   'use',
#   'pay'],
#  ['clearly', 'put', 'quite', 'informative'],
#  ['might',
#   'mention',
#   'how',
#   'balance',
#   'transfer',
#   u'affect',
#   'credit',
#   'card',
#   'transferring',
#   'balance',
#   'might',
#   'common',
#   'knowledge',
#   'credit',
#   'card',
#   'world',
#   'information',
#   'seek'],
#  ['how',
#   'long',
#   '0',
#   'interest',
#   '?',
#   'how',
#   'long',
#   'start',
#   'charging',
#   'interest',
#   '?'],
#  ["not_'s", 'perfect', 'explain', 'plainly', 'simple', 'thanks', 'alot'],
#  ['?', 'how', 'pay', 'high', 'interest', 'loan', 'quickly', '?'],
#  ['helpful'],
#  [],
#  ['everything', 'needed', 'know', 'thank'],
#  ['thank'],
#  ['best',
#   'card',
#   'transfer',
#   '18,000',
#   'debt',
#   'already',
#   'chase',
#   'bank',
#   'card',
#   'wo',
#   'not_allow',
#   'transfer',
#   u'card',
#   'not_charge',
#   'fee',
#   '?'],
#  ['moved', 'slate', 'card', u'finance', 'need', 'help', 'time'],
#  ['need',
#   'pay',
#   '25000in',
#   'credit',
#   'card',
#   'husband',
#   'cancer',
#   'take',
#   'retirement',
#   'went',
#   'income',
#   'ca',
#   'not_pay',
#   'need',
#   'help'],
#  ['informative'],
#  ['article', 'truly', 'explained', 'art', 'balance', 'transfer', 'thanks'],
#  ['thanks'],
#  ['nan'],
#  ['looking', 'coolest', 'wether', 'wise', 'phoenix'],
#  ['ca', 'not_get', 'fico', 'score', '?', '?'],
#  ['want', 'know', 'what', 'actual', u'number', 'what', 'mean'],
#  ['fico', u'score', 'cra', u'score', 'two', 'different', u'thing'],
#  ['want', 'free', 'copy', 'whatever', 'credit', u'report'],
#  ['never', u'say', 'how', 'much', 'add', 'minimum', 'payment'],
#  ['thank'],
#  ['unrealistic', 'advice'],
#  ['easy', 'read', 'informative', 'helpful'],
#  [],
#  [],
#  ['thank',
#   'excellent',
#   'tutorial',
#   'how',
#   'credit',
#   u'card',
#   'work',
#   'newbie'],
#  ['informative'],
#  ['helpful', 'information'],
#  ['visiting',
#   'someone',
#   'put',
#   'stuff',
#   'card',
#   'pay',
#   'end',
#   'check',
#   'what',
#   'avoid',
#   u'fee',
#   'card',
#   'not_get',
#   'normal',
#   'use',
#   u'fee',
#   'cause',
#   'pushed',
#   'limit',
#   'card',
#   'use'],
#  ['detailed', 'easy', 'understand', 'writeup', 'huge', 'thank', 'author'],
#  ['never', 'knew', 'difference', 'thanks'],
#  ['many',
#   'maybe',
#   'article',
#   'know',
#   'when',
#   'credit',
#   'score',
#   'actually',
#   'impacted'],
#  ['what', u'creditor', 'see'],
#  ['people',
#   'cash',
#   '5,000',
#   'furniture',
#   u'purchase',
#   'not_searching',
#   'online',
#   'advice',
#   'purchasing',
#   'furniture',
#   'credit',
#   'although',
#   'everyone',
#   u'know',
#   'cash',
#   'always',
#   'best',
#   'article',
#   'geared',
#   'toward',
#   'who',
#   'not_extra',
#   'cash',
#   'lying',
#   'around'],
#  ['name', 'company', 'credit', u'card', 'furniture', 'store'],
#  ['keep', 'giving', 'advice', u'u', 'need', 'help'],
#  [],
#  ['helpful', 'explanation'],
#  ['what', 'current', 'advice', 'refinancing', '?'],
#  ['high',
#   'piont',
#   'gratitude',
#   'nice',
#   'when',
#   'people',
#   'give',
#   'detail',
#   'what',
#   'asking',
#   'looking',
#   'for.for',
#   'people',
#   'not_knowing.thank'],
#  ['son',
#   'military',
#   'trying',
#   'get',
#   'loan',
#   'information',
#   'helpful',
#   'important'],
#  ['definitely', 'found', u'question', 'ask', 'lender', 'helpful'],
#  ['thank', 'new', 'gave', 'reassurance', 'starting', 'process'],
#  ['informative', 'information', 'thank'],
#  ['not_discuss', 'best', u'lender', 'least', 'risky', u'borrower'],
#  ['awesome',
#   u'thing',
#   'know',
#   'reading',
#   'also',
#   u'make',
#   'confirm',
#   'what',
#   'already',
#   'know',
#   u'keep',
#   'date'],
#  ['not_specif', 'how', 'repair', 'credit', 'need', 'direction'],
#  ['thank', 'helpful', 'god', 'bless'],
#  ['lo'],
#  ['where', 'laramie'],
#  ['whats',
#   'answer',
#   '?',
#   'better',
#   'using',
#   'credit',
#   'card',
#   'directly',
#   'using',
#   'credit',
#   'card',
#   'payal',
#   '?'],
#  ['need', u'city', 'information'],
#  [],
#  ['thanks', 'understandable'],
#  ['not_answer', 'question'],
#  ['everything'],
#  ['need',
#   'find',
#   'not_report',
#   'something',
#   'dosnt',
#   'seem',
#   'right',
#   'losing',
#   'wallet'],
#  ['useless'],
#  ['nope', 'bush'],
#  ['say', 'how', 'locate', 'card'],
#  ['not_help', 'find'],
#  ['common', 'sense', 'retarded'],
#  ['lol'],
#  ['what', 'misplaced'],
#  ['like', u'cooky'],
#  ['first',
#   'day',
#   'debit',
#   'card',
#   'went',
#   'missing',
#   'went',
#   'bank',
#   'blocked',
#   'not_cancelled',
#   'filled',
#   'paper',
#   'word',
#   'new',
#   'card',
#   'number',
#   'blocked',
#   'differ',
#   'cancelled',
#   '?'],
#  ['everything'],
#  [],
#  ['want', 'know', 'where'],
#  ['still', 'ca', 'not_find', 'debit'],
#  ['not_list', 'viable', u'step', 'poorly', 'written'],
#  ['keep', 'flow', 'open', 'info'],
#  ['thanks', 'bruh'],
#  ['what',
#   'bank',
#   u'increase',
#   'limit',
#   'without',
#   'offering',
#   'hard',
#   'inquire',
#   '?'],
#  ['hard',
#   'inquiry',
#   'credit',
#   'best',
#   'made',
#   'higher',
#   'limit',
#   'lower',
#   'one',
#   'correct',
#   '?',
#   'example',
#   'new',
#   'capital',
#   'one',
#   'card',
#   'initial',
#   'deposit',
#   'determines',
#   'how',
#   'high',
#   'limit',
#   'want',
#   'avoid',
#   'making',
#   'another',
#   'hard',
#   'inquiry',
#   'higher',
#   'limit',
#   'starting',
#   'higher',
#   'limit',
#   'needed',
#   'make',
#   'sense',
#   '?'],
#  ['not_give', 'much', 'answer'],
#  ['transunion',
#   u'report',
#   'ideal',
#   'usage',
#   'ratio',
#   'available',
#   'credit',
#   'individual',
#   'card',
#   'overall',
#   '25',
#   'using',
#   u'le',
#   '25',
#   u'le',
#   'advantageous',
#   'score',
#   'staying',
#   '25-30',
#   'range',
#   'thus',
#   'receiving',
#   'credit',
#   'limit',
#   'high',
#   'not_using',
#   '25',
#   'would',
#   'actually',
#   'harm',
#   'one',
#   'credit',
#   'score',
#   'better',
#   'distribute',
#   'charging',
#   'payment',
#   u'pattern',
#   'given',
#   'card',
#   '25-30',
#   'limit',
#   'use',
#   'on-time',
#   u'payment'],
#  ['vague', 'information', 'incomplete', 'propbably', 'not_true'],
#  ['everthying'],
#  ['ballsac', 'dong'],
#  ['fear',
#   'mongering',
#   'far',
#   'fetched',
#   'think',
#   'anybody',
#   'going',
#   'get',
#   'trouble',
#   'case',
#   'referenced',
#   'bad',
#   'reference',
#   'man',
#   'fraud',
#   'not_nearly',
#   'simple',
#   'lying',
#   'income',
#   'gained',
#   'surely',
#   'person',
#   'who',
#   'wrote',
#   u'know',
#   u'article',
#   'tell',
#   'truth',
#   'keep',
#   'mouth',
#   'shut',
#   'not_want',
#   'say',
#   'nothing',
#   'bad',
#   'happen',
#   'lying',
#   'reality',
#   'suggests',
#   'not_state',
#   'imply',
#   'false',
#   u'statement'],
#  ['statist', 'fearmongering'],
#  ['informative'],
#  ['helpful'],
#  ['how', 'find', u'apartment', u'owner', '?', 'where', 'look'],
#  ['thank'],
#  ['delicious'],
#  ['moving',
#   'soon',
#   'helpful',
#   '18',
#   'hard',
#   'when',
#   'ca',
#   'not_find',
#   'information',
#   'anywhere',
#   'else'],
#  ['not_clear', 'enough'],
#  ['where', 'find', 'apts', u'house', 'dont', 'check', 'credit'],
#  ['thanks', 'help', 'great', 'info'],
#  ['how', 'find', u'owner'],
#  ['puus'],
#  ['clear-cut', 'precisely', 'what', 'needed'],
#  ['hello',
#   'mira',
#   'steve',
#   'private',
#   'loan',
#   'lender',
#   'who',
#   u'give',
#   'life',
#   'time',
#   'opportunity',
#   u'loan',
#   'need',
#   'urgent',
#   'loan',
#   'clear',
#   u'debt',
#   'need',
#   'capital',
#   'loan',
#   'improve',
#   'business',
#   '?',
#   'rejected',
#   u'bank',
#   'financial',
#   u'agency',
#   '?',
#   'need',
#   'consolidation',
#   'loan',
#   'mortgage',
#   '?',
#   'search',
#   'not_make',
#   'financial',
#   u'problem',
#   'thing',
#   'past',
#   'loan',
#   u'fund',
#   u'individual',
#   'need',
#   'financial',
#   'assistance',
#   'bad',
#   'credit',
#   'need',
#   'money',
#   'pay',
#   u'bill',
#   'invest',
#   'business',
#   'rate',
#   '2',
#   'want',
#   'use',
#   'medium',
#   'inform',
#   'render',
#   'reliable',
#   'beneficiary',
#   'assistance',
#   'willing',
#   'offer',
#   'loan.so',
#   'email',
#   u'u',
#   'today',
#   'miraloan1',
#   'gmail.com'],
#  [],
#  ['considate'],
#  [],
#  ['great', u'answer', 'learned', 'lot', 'reading'],
#  ['not_answer', 'how', 'get', 'co-signer'],
#  ['thank', 'much', 'helpful'],
#  ['want', 'know', 'law', 'remove', 'name', 'cosigner'],
#  ['need', 'know', 'how', 'co', 'signed', 'remove', 'car', 'loan'],
#  ['not_moment'],
#  ['option'],
#  ['want', 'know', 'how', 'get', 'name', 'loan'],
#  ['not_pay',
#   'anything',
#   'cosigned',
#   'apartment',
#   'not_lived',
#   'since',
#   'oct',
#   'call',
#   'like',
#   'every',
#   'three',
#   u'month'],
#  ['thought',
#   'suppose',
#   'help',
#   'getting',
#   'cosign',
#   'instead',
#   'everything',
#   'trying',
#   'avoid'],
#  ['cosign',
#   '4',
#   'apartment',
#   'people',
#   'cosign',
#   'left',
#   'without',
#   'knowledge',
#   'happened',
#   'lafayette',
#   'colorado',
#   'people',
#   'cosign',
#   'moved',
#   '2',
#   'georgia',
#   'business',
#   'stuck',
#   'death',
#   'course',
#   'affecting',
#   'credit',
#   'people',
#   'cosine',
#   '4',
#   'want',
#   'nothing',
#   'anymore',
#   'stock',
#   'whit',
#   'almost',
#   '4000',
#   'dolars',
#   'debt',
#   'what',
#   'recourse',
#   'thank'],
#  [],
#  ['not_guidelines', 'what', 'good', 'rate', 'actually'],
#  ['682',
#   'credit',
#   'score/',
#   '52k',
#   'income',
#   'lending',
#   'club/lending',
#   'tree',
#   'turned',
#   u'suggestion',
#   'applicable',
#   '?'],
#  ['doesnt', 'list', 'actual', u'lender'],
#  ['want', 'personal', 'loan', 'asked', 'everything', 'else'],
#  ['great', 'advice', 'thank'],
#  ['big', 'help', 'thx'],
#  ['thanks', 'understood'],
#  ['not_thank'],
#  ['good'],
#  ['not_give', 'loan'],
#  ['maybe', 'payment', 'table', u'period', 'likely', 'interest'],
#  [],
#  ['much', 'general', 'information', 'not_real', u'fact'],
#  ['information', 'answered', u'question'],
#  ['straight'],
#  ['cool'],
#  ['well', 'done'],
#  [],
#  ['good', 'simply', 'easy', 'understand'],
#  ['everything'],
#  ['how',
#   'consumer',
#   'win',
#   '?',
#   'payoff',
#   'cc',
#   'ding',
#   'not_payoff',
#   'ding',
#   'what',
#   'realistic',
#   'obtainable',
#   'way',
#   'increase',
#   u'score',
#   'quicker'],
#  ['not_specifically', 'show', 'how', 'make', 'money'],
#  ['pretty', 'basic', 'would', 'useful'],
#  ['yes'],
#  ['vague',
#   'basically',
#   'answer',
#   'not_reimbursing',
#   'employee',
#   u'cost',
#   'personal',
#   'card',
#   'get',
#   'messy',
#   'however',
#   'everything',
#   'online',
#   'easy',
#   u'day',
#   'really',
#   'walkthrough',
#   'two',
#   u'scenario',
#   'screenshots',
#   'popular',
#   u'card',
#   'accounting',
#   'software',
#   'not_speak',
#   'whimsically',
#   'speak',
#   'ceo',
#   'using',
#   'help',
#   'guide',
#   'rather',
#   'morning',
#   'read',
#   'train'],
#  ['not_cost',
#   'creditor',
#   'report',
#   'credit',
#   'information',
#   'credit',
#   u'bureau'],
#  ['thank',
#   'john',
#   u'supplement',
#   'tony',
#   'armstrong',
#   'article',
#   'young',
#   'aspiring',
#   'investor',
#   u'article',
#   'definitely',
#   'opened',
#   'whole',
#   'new',
#   'playground'],
#  [],
#  ['not_address', u'question', 'purchasing', 'debit', 'card'],
#  ['clear', 'concise', 'information', 'clearly', 'stating', u'difference'],
#  ['not_know',
#   'cashier',
#   'check',
#   'safest',
#   'way',
#   'send',
#   'receive',
#   'money',
#   'great',
#   'deal',
#   'help',
#   'thank'],
#  ['not_what',
#   'fucking',
#   'looking',
#   'not_metatag',
#   'shit',
#   'page',
#   'show',
#   'top',
#   'google'],
#  ['want', 'know', 'cashing', 'check'],
#  ['cashier', 'check', 'good', 'international', u'purchase', '?'],
#  ['bank', u'link'],
#  ['how', 'long', 'hold', 'cashier', 'check'],
#  ['need', 'info', 'certified', u'check', 'opposed', 'cashier', u'check'],
#  ['already',
#   'knew',
#   u'bank',
#   'sold',
#   'high',
#   'fee',
#   'question',
#   'where',
#   'else',
#   'purchase',
#   u'cashier',
#   u'check',
#   '?',
#   'post',
#   u'office',
#   '?',
#   u'supermarket',
#   '?'],
#  ['bank',
#   'say',
#   'charles',
#   'schwab',
#   'not_branches',
#   'not_chase',
#   'td',
#   'boa',
#   'what',
#   '?',
#   '?'],
#  ['tell', u'u', 'where', 'bank', 'obtain', 'one'],
#  ['disabled',
#   'not_go',
#   'bank',
#   'must',
#   'buy',
#   'online',
#   '?',
#   '?',
#   '?',
#   'phone',
#   '?'],
#  ['what',
#   'happens',
#   'find',
#   'item',
#   'not_what',
#   'advertised',
#   'changed',
#   'mind',
#   'not_want',
#   'buy',
#   'what',
#   u'cashier',
#   'check'],
#  ['searching', 'cash', 'cashier', 'check', 'not_info'],
#  ['thank', 'info', 'appreciate', 'summed', 'question', 'helpful'],
#  ['possible',
#   'get',
#   'cashier',
#   'check',
#   'without',
#   'local',
#   'bank',
#   'account',
#   '?'],
#  ['informative',
#   'liked',
#   'fact',
#   'difference',
#   'cashier',
#   'check',
#   'certified',
#   'check',
#   'money',
#   'order',
#   'explained',
#   'thank',
#   'j'],
#  ['u', 'not_tell', 'shit', 'cunt', 'scab'],
#  ['great',
#   'job',
#   'keeping',
#   'legal',
#   'jargon',
#   'low',
#   'understandability',
#   'high'],
#  ['want', 'know', 'how', 'good', 'bad', 'credi'],
#  ['terrible',
#   'article',
#   'not_answer',
#   'essential',
#   'question',
#   'come',
#   'nerd',
#   'wallet'],
#  [u'beat', 'around', 'bush'],
#  ['not_explain', '8', 'fico', 'score', 'good', 'bad'],
#  ['ex',
#   'took',
#   'credit',
#   'card',
#   'used',
#   'without',
#   'permission',
#   'wat',
#   'shud',
#   '?'],
#  [u'suck'],
#  ['not_answer', 'question'],
#  ['not_right', 'info'],
#  ['not_@', '23r'],
#  ['life', 'wrong'],
#  ['federal', u'penalty'],
#  ['understanding',
#   'state',
#   'different',
#   u'law',
#   'still',
#   'wanting',
#   'know',
#   'what',
#   u'amount',
#   'involved',
#   'tend',
#   'determine',
#   'severity/level',
#   u'charge'],
#  ['wish',
#   'would',
#   'include',
#   'amount',
#   'money',
#   'taking',
#   'people',
#   'who',
#   'fraud',
#   'based',
#   'amount',
#   'explain',
#   'petty'],
#  ['wanted',
#   'know',
#   'debt',
#   'paid',
#   'how',
#   'long',
#   'take',
#   'credit',
#   'score',
#   'go',
#   u'point',
#   '?',
#   'really',
#   'not_give',
#   'straight',
#   'answer'],
#  ['not_tell', 'how', 'get', 'credit', 'score'],
#  ['pay', 'debt', 'mean', 'tell', 'credit', 'score', 'drop'],
#  ['not_info', 'building'],
#  ['not_explain',
#   'how',
#   'credit',
#   'score',
#   'system',
#   'made',
#   'what',
#   'today',
#   'included',
#   'ex',
#   u'form',
#   'credit',
#   'scoring'],
#  ['thanks'],
#  ['nope'],
#  ['good', 'info'],
#  ['simplistic', 'informative'],
#  ['eye', 'opener'],
#  ['include', 'updated', 'information', 'table', 'would', 'nice'],
#  ['need', 'explain', 'what', '3', 'month', 'cd', 'bring'],
#  ['what',
#   'best',
#   'way',
#   'invest',
#   '?',
#   'work',
#   'hard',
#   'little',
#   'family',
#   '2000',
#   'invest',
#   'risk',
#   'would',
#   'like',
#   'get',
#   'quick',
#   'return',
#   'consistently',
#   'maybe',
#   'penny',
#   u'stock',
#   '?'],
#  ['would', 'loove', 'see', 'updated', 'review'],
#  ['helped',
#   'decide',
#   'installment',
#   'loan',
#   'not_worth',
#   'interest',
#   'going',
#   'pay',
#   'vs.',
#   'small',
#   'bump',
#   'credit',
#   'score',
#   'would',
#   'result'],
#  ['nerdwallet',
#   'best',
#   'web',
#   'site',
#   'lay',
#   'person',
#   'understand',
#   'thank',
#   'help'],
#  ['trying', 'buy', 'home', 'article', 'helpful'],
#  ['history',
#   u'saving',
#   'account',
#   'interest',
#   'what',
#   'looking',
#   'got',
#   'nice',
#   'historical',
#   'overview',
#   'industry'],
#  ['keep', 'good', 'work'],
#  ['stupid'],
#  ['idk'],
#  ['nerdwallet', 'good', 'resource', 'often', 'use', 'keep', 'good', 'work'],
#  ['looking',
#   'how',
#   'often',
#   'request',
#   'increase',
#   'without',
#   'damaging',
#   'credit'],
#  ['helpful'],
#  ['basic'],
#  ['great'],
#  ['general',
#   'common',
#   'sense',
#   u'answer',
#   'apply',
#   'first-time',
#   'credit',
#   u'user'],
#  ['lack', 'concreate', 'info', 'average', 'known', 'info'],
#  ['helpful'],
#  [],
#  [],
#  ['straight', 'point'],
#  ['gay'],
#  ['thanks', 'really', 'helped', 'find', 'better', 'understanding'],
#  [u'help',
#   'young',
#   'credit',
#   u'user',
#   'understand',
#   'credit',
#   'bit',
#   'better'],
#  ['article', 'merchant', 'not_give', 'much', 'information', 'consumer'],
#  ['really', 'appreciate', 'kind', 'information'],
#  ['not_info', u'rate'],
#  [u'detail', 'would', 'helpful'],
#  ['great',
#   'article',
#   'insightful',
#   'helped',
#   'grasp',
#   u'concept',
#   'fixed-rate',
#   u'mortgage',
#   'compared',
#   u'arm'],
#  ['great', 'information'],
#  [],
#  ['thank', 'helped', 'lot'],
#  ['how', 'cancel', 'money', 'order', '?'],
#  ['googled', 'what', 'paid', 'money', 'order'],
#  ['nah'],
#  ['purchaser', 'address'],
#  ['what',
#   'happens',
#   'send',
#   'money',
#   'order',
#   'not_receive',
#   'item',
#   'paid',
#   '?'],
#  ['good', 'info'],
#  ['where', 'money', 'come', '?'],
#  ['how', 'sent'],
#  ['looking', u'fee', 'charged', 'different', u'location'],
#  ['get',
#   'money',
#   'order',
#   'bank',
#   'not_use',
#   'return',
#   u'fund',
#   'redeposited',
#   '?'],
#  ['thank'],
#  ['great', u'thing', 'know'],
#  ['informative'],
#  ['nothing', 'great', 'thanks'],
#  ['yes'],
#  ['what',
#   'forgot',
#   'sign',
#   'name',
#   'money',
#   'order',
#   'money',
#   'order',
#   'bill',
#   'already',
#   'mailbox'],
#  [u'restriction', 'age', 'not_shown'],
#  ['needed', 'information', 'cancelation', 'money', u'order'],
#  ['explain', u'detail'],
#  ['everything'],
#  [],
#  ['what', 'information', 'need', 'send', '?'],
#  ['check', 'see', 'money', 'order', 'cashed', '?'],
#  ['nope'],
#  ['how', 'get', 'aprov'],
#  ['hope', 'get', 'approved', 'put', u'debt', 'one', 'card'],
#  [],
#  ['thanks'],
#  [],
#  ['18th', 'month', '0', 'what', 'account', 'rate', '?'],
#  ['gill'],
#  ['yes',
#   'ive',
#   'last',
#   'two',
#   u'month',
#   'going',
#   '30',
#   '3-10',
#   u'dollar',
#   'credit',
#   'score',
#   u'keep',
#   'dropping',
#   'im',
#   'getting',
#   'frustrated',
#   u'time',
#   'hard',
#   'ive',
#   'going',
#   'know',
#   'choice',
#   'im',
#   'gon',
#   'na',
#   'pay',
#   'balance',
#   'full',
#   'thursday',
#   'let',
#   'card',
#   'rest',
#   'how',
#   'rebuild',
#   'score',
#   '?',
#   u'suggestion'],
#  [],
#  ['would',
#   'amend',
#   'suggest',
#   'credit',
#   'card',
#   'holder',
#   'find',
#   'information',
#   'credit',
#   'card',
#   'company',
#   u'report',
#   'credit',
#   u'service',
#   'report',
#   'transaction',
#   'activity',
#   'month',
#   'well',
#   'point-in-time',
#   'card',
#   'balance'],
#  ['inaccurate', 'information'],
#  ['article', 'helpful'],
#  ['something',
#   'done',
#   '30',
#   'business',
#   'credit',
#   'reporting',
#   u'agency',
#   'become',
#   u'bully',
#   u'dictator',
#   'long',
#   'pay',
#   u'bill',
#   'full',
#   'time',
#   'able',
#   'use',
#   'what',
#   'want',
#   'need',
#   'time',
#   'seems',
#   'unconstitutional',
#   'where',
#   'constitutional',
#   u'right',
#   'go',
#   '?',
#   '?',
#   '?'],
#  ['need',
#   'know',
#   'income',
#   u'increase',
#   'alert',
#   'credit',
#   'card',
#   u'company',
#   '?',
#   'question',
#   'asked',
#   'google',
#   'sent',
#   'thanks'],
#  [u't', 'what', 'new', 'written', 'stone'],
#  [],
#  ['not_thanks'],
#  ['not_thanks'],
#  ['article',
#   'helped',
#   'make',
#   'positive',
#   u'decision',
#   'towards',
#   'relationship',
#   'money',
#   'thanks'],
#  ['could', 'suggest', u'company', 'offer', 'prepaid', 'debit', u'card', '?'],
#  ['great',
#   'informative',
#   'article',
#   'confused',
#   'teen',
#   'date',
#   'thanks',
#   'lot'],
#  ['although', 'wish', 'would', 'compared', 'real', u'card', u'example'],
#  ['nice', 'job', u'buckaroo'],
#  ['need',
#   'contact',
#   'management',
#   'tool',
#   'use',
#   'justphonebook',
#   'free',
#   'sync',
#   'manage',
#   'exchange',
#   'business',
#   u'contact',
#   u'colleague',
#   'device',
#   u'http'],
#  ['perfect', 'advise', 'small', 'business', u'owner'],
#  ['needed',
#   'small',
#   'business',
#   'app',
#   'track',
#   u'expense',
#   'like',
#   'mileage',
#   'invoice',
#   u'client'],
#  [u'lack', u'receipt', 'info'],
#  ['not_best', 'apps', 'new', 'business'],
#  ['article',
#   'seems',
#   'focused',
#   'selling',
#   'paid',
#   'apps',
#   'not_everyone',
#   u'want',
#   'spend',
#   'money',
#   'apps',
#   'free'],
#  ['like'],
#  ['thank', 'much', 'helpful', 'information..'],
#  ['not_details'],
#  ['not_link', 'clicked', 'brought', 'reason', 'when'],
#  ['vague', 'not_answer', 'question', 'directly'],
#  [u'as'],
#  ['need',
#   'info',
#   'like',
#   u'point',
#   'toward',
#   'credit',
#   'score',
#   'paid',
#   'car'],
#  ['straight', 'answer'],
#  [],
#  ['love', 'site'],
#  [u'need', u'detail'],
#  ['hyperbole'],
#  ['nice'],
#  ['need', 'help', 'tell', 'one', 'not_card', 'fee'],
#  ['everything'],
#  ['not_clarification',
#   'credit',
#   'scoring',
#   'article',
#   'agree',
#   'process',
#   'complicated',
#   'confusing',
#   'help',
#   'make',
#   u'thing',
#   'fair',
#   'when',
#   'see',
#   'word',
#   'nerd',
#   'expect',
#   'depth',
#   'information',
#   'not_shoulder',
#   'shrugging',
#   'article',
#   'saying',
#   'yeah',
#   'tough',
#   'mercy',
#   'credit',
#   u'company',
#   'almost',
#   'not_guidelines',
#   'how',
#   'score',
#   'generated',
#   'what',
#   u'factor',
#   u'le',
#   'important',
#   'how',
#   'effectively',
#   'change',
#   u'factor',
#   'positive',
#   'way',
#   u'nerd'],
#  ['great', 'article', 'easy', 'understand', 'answered', 'lot', u'question'],
#  ['not_thanks', 'help'],
#  [],
#  ['not_say', 'how', 'initiate', 'payment'],
#  ['helpful', 'totally', 'not_help', 'what', 'need'],
#  ['basically',
#   'getting',
#   'credit',
#   'good',
#   'building',
#   'credit',
#   'b.s',
#   'reward',
#   u'point',
#   'get',
#   '?',
#   'thanks',
#   'worthless',
#   'info'],
#  ['vague'],
#  ['tell', u'u', 'law', 'not_why', 'feel', 'bad', u'merchant'],
#  ['made',
#   'everything',
#   'pretty',
#   'clear',
#   'understand',
#   'also',
#   'going',
#   'forward',
#   'little',
#   u'le',
#   'irate',
#   'when',
#   'credit',
#   'card',
#   'minimum'],
#  ['yes',
#   'thanks',
#   'information',
#   'great',
#   'help',
#   'how',
#   'remove',
#   'search',
#   'bank',
#   'rejected',
#   'home',
#   'loan',
#   'told',
#   'check',
#   'credit',
#   'score',
#   'found',
#   'vodafone',
#   'reported',
#   '3',
#   u'time',
#   'bill',
#   'not_.so',
#   'vodafone',
#   u'lie',
#   'removed',
#   'ca',
#   'not_get',
#   'hsbc',
#   'checked',
#   'removed',
#   'say',
#   'information',
#   'correct',
#   'time',
#   'checked.so',
#   'ca',
#   'not_borrow',
#   'anyone',
#   'else',
#   'due',
#   'declined',
#   'check',
#   'help'],
#  ['gobble', 'gobble', 'bag', 'humbug'],
#  ['reading',
#   'artical',
#   'reinforced',
#   'original',
#   u'plan',
#   'build',
#   'credit',
#   'additional',
#   u'link',
#   u'option',
#   'caution',
#   'big',
#   u'purchase',
#   u'payment'],
#  ['not_professionally', 'presented'],
#  ['question',
#   'how',
#   'long',
#   'due',
#   'date',
#   u'show',
#   'late',
#   'credit',
#   'never',
#   'directly',
#   'answered'],
# ...
#   'someone',
#   'establishing',
#   'credit'],
#  ['great', 'artical'],
#  ['provided', 'great', 'understanding', '2', u'card'],
#  ['thanks'],
#  ['thank', 'informationit', 'helped'],
#  ['who', 'time', 'research', 'write', 'stuff', 'guess', u'nerd', 'a+'],
#  ['great', u'card'],
#  ['credit', u'score', 'qualify'],
#  ['none'],
#  ['loved', 'informative'],
#  ['misleading', 'data', 'absolutely', 'not_area', 'bay', 'affordable'],
#  ['card', 'give', 'high', 'credit', 'mortgage', 'purposrates'],
#  ['title',
#   'article',
#   'not_answered',
#   'instead',
#   'advice',
#   'apply',
#   'card',
#   'leave',
#   'cancel',
#   'amex',
#   'due',
#   'large',
#   'annual',
#   'renewal',
#   'fee',
#   'credit',
#   'card'],
#  ['want', 'apply'],
#  ['great', 'job', 'thanks'],
#  ['not_know', 'one', 'pay', 'first'],
#  [],
#  [],
#  ['not_thanks'],
#  ['what',
#   'word',
#   'fico',
#   'stand',
#   '?',
#   'who',
#   'give',
#   'secure',
#   'credit',
#   'card',
#   '?',
#   'like',
#   'many',
#   'question',
#   'unanswerd'],
#  [u'article', 'clear', 'point', 'thank', 'informative', 'reading'],
#  ['better',
#   u'option',
#   'exist',
#   'article',
#   'either',
#   'poorly',
#   'researched',
#   'outdated'],
#  ['not_enough', u'detail'],
#  ['inaccurate'],
#  ['feel',
#   'like',
#   u'card',
#   'stated',
#   'best',
#   'not_really',
#   'best',
#   'failed',
#   'mention',
#   'american',
#   'express',
#   'hhilton',
#   u'honor',
#   'card',
#   u'offer',
#   '5',
#   u'time',
#   'restaurant',
#   u'charge'],
#  ['yall', 'wack'],
#  ['fuck', 'police', u'bank'],
#  ['ur', 'mum'],
#  ['everything'],
#  ['bush', '9/11'],
#  ['not_explaine', 'well'],
#  ['good', 'advice', 'thanks'],
#  ['good',
#   u'article',
#   'really',
#   'enjoy',
#   'reading',
#   'credit',
#   'score',
#   '470',
#   'year',
#   'ago',
#   'thru',
#   'reading',
#   'advice',
#   'im',
#   '605',
#   'im',
#   'getting',
#   'thanks',
#   u'guy'],
#  ['thanks'],
#  ['not_credit',
#   'got',
#   'married',
#   'young',
#   'beautiful',
#   'baby',
#   'boy',
#   'divorced',
#   '7',
#   u'year',
#   'later',
#   'not_credit',
#   'help',
#   'small',
#   'stuff',
#   'need',
#   'hope',
#   'find',
#   'something',
#   u'help'],
#  [],
#  ['article', 'bad', 'feel', 'bad'],
#  [],
#  ['need',
#   'credit',
#   'card',
#   'help',
#   'build',
#   'credit',
#   'get',
#   'denied',
#   'not_credit'],
#  [],
#  [],
#  ['yes',
#   'put',
#   'money',
#   u'account',
#   'use',
#   'right',
#   '?',
#   '?',
#   '?',
#   '?',
#   'way',
#   'use',
#   '?',
#   '?',
#   '?',
#   '?'],
#  ['help', 'make', 'better', 'choice', 'card'],
#  ['great',
#   'advice',
#   'took',
#   'three',
#   'credit',
#   u'card',
#   'maintain',
#   u'balance',
#   'credit',
#   'score',
#   'increased',
#   'significantly',
#   'way',
#   'home',
#   'ownership'],
#  ['always',
#   'wanted',
#   'know',
#   'how',
#   'build',
#   'credit',
#   'increase',
#   'score..',
#   'article',
#   'people',
#   'who',
#   'middle',
#   'ground',
#   'credit',
#   'little',
#   'income',
#   u'saving',
#   'what',
#   'key',
#   'increase',
#   'credit',
#   'score',
#   'shortest',
#   'time'],
#  ['what',
#   'canada',
#   '?',
#   u'article',
#   'could',
#   'specify',
#   u'u',
#   'content',
#   'ecample',
#   '3',
#   'credit',
#   'repirting',
#   u'agency',
#   'canada',
#   '?',
#   'recognize',
#   '2',
#   'thx'],
#  ['yes',
#   'score',
#   '530',
#   '1',
#   '541',
#   'thing',
#   'get',
#   'approve',
#   'secure',
#   'card',
#   '?'],
#  ['good', 'information', 'especially', 'someone', 'trying', 'rebuild', 'like'],
#  ['please', 'list', 'secure', u'card', 'thanks'],
#  ['mention',
#   '2',
#   u'card',
#   'better',
#   'one',
#   'example',
#   'best',
#   'starting',
#   'point',
#   'not_3',
#   'secured',
#   'credit',
#   'card',
#   u'application',
#   'within',
#   'certain',
#   'time',
#   'frame',
#   'income',
#   'deposit',
#   u'fund',
#   'available',
#   'thanks'],
#  ['none', 'time', 'thsnk', 'fot', 'assistance'],
#  ['want', 'know', u'similarity', 'two'],
#  ['bad',
#   'credit',
#   'need',
#   'urgent',
#   'loan',
#   'solve',
#   'pressing',
#   'need',
#   '?',
#   'lend',
#   'secured',
#   'unsecured',
#   u'loan',
#   'honest',
#   'reliable',
#   u'individual',
#   u'company',
#   'globally',
#   '3',
#   'interest',
#   'rate',
#   'solution',
#   'financial',
#   'problem',
#   'also',
#   'need',
#   'money',
#   'project',
#   'business',
#   u'tax',
#   u'bill',
#   'many',
#   'others',
#   'reason',
#   'contact',
#   u'u',
#   'today',
#   'loan',
#   'desire',
#   'arrange',
#   'loan',
#   'suit',
#   'budget',
#   'low',
#   'interest',
#   'rate.contact',
#   u'u',
#   'mrhamdnloanoffer',
#   'gmail.com'],
#  ['boyfriend',
#   '6',
#   u'month',
#   'major',
#   'credit',
#   'card',
#   'debut',
#   'divorced',
#   '5',
#   u'year',
#   'ago',
#   u'travel',
#   'career',
#   'racked',
#   'debt',
#   'came',
#   'lump',
#   'sum',
#   'money',
#   'ex',
#   'back',
#   'child',
#   'support',
#   'keep',
#   'saying',
#   'acting',
#   'like',
#   'help',
#   'financially',
#   'single',
#   'mom',
#   'never',
#   'get',
#   'lump',
#   'sum'],
#  ['not_say', 'good', 'bad', 'credit'],
#  ['c.c', 'people', 'bad', 'credit'],
#  [],
#  [],
#  ['many', 'common', 'sense', 'writing'],
#  ['how', 'transfer'],
#  ['doesnt',
#   'explain',
#   'how',
#   'use',
#   'check',
#   'like',
#   'title',
#   u'say',
#   u'say',
#   'what',
#   'check'],
#  ['need', 'national', 'opt', u'company', 'already', 'business'],
#  ['great', 'info', 'take', 'consideration', 'thanks'],
#  ['helpful', 'well', 'detailed'],
#  ['already',
#   'knew',
#   'itin',
#   'number',
#   'used',
#   'pay',
#   u'tax',
#   'not_apply',
#   'credit',
#   'card',
#   'although',
#   'lady',
#   'bank',
#   'america',
#   'told',
#   'itin',
#   'number',
#   'checking',
#   'account',
#   'would',
#   'free',
#   'also',
#   'looking',
#   u'loan',
#   'itin',
#   'number',
#   'holders..also',
#   'irs',
#   'really',
#   'help',
#   u'foreigner',
#   'not_immigration',
#   'must',
#   'want',
#   'keep',
#   'track',
#   'money',
#   'owed',
#   'lol'],
#  ['good', 'news'],
#  ['horrible'],
#  [],
#  ['thank'],
#  ['really', 'good', 'info'],
#  ['everything'],
#  ['provide', 'security', 'deposit', u'card', 'info'],
#  ['not_answer',
#   'question',
#   'how',
#   'where',
#   'figure',
#   'how',
#   'long',
#   'interest',
#   '0'],
#  ['clear', 'concise', 'published', 'www'],
#  ['looking',
#   'cheap',
#   'interest',
#   'rate',
#   'advise',
#   'who',
#   'best',
#   'also',
#   'best',
#   u'rate',
#   u'saving',
#   'thanks',
#   'allen',
#   'ward',
#   '0432048588'],
#  ['where',
#   u'card',
#   'low-income',
#   '?',
#   'make',
#   'far',
#   u'le',
#   '15k',
#   'year',
#   'never',
#   'made',
#   'credit',
#   'score',
#   '740',
#   '10+years',
#   'credit',
#   'history',
#   'looking',
#   u'option',
#   'low',
#   'income',
#   u'card'],
#  ['knew',
#   'thus',
#   'sent',
#   'credit',
#   u'offer',
#   'stll',
#   'denied',
#   'whole',
#   'business',
#   'joke'],
#  ['how', 'long', 'person', 'wait', 'applying', '?'],
#  ['update',
#   'article',
#   'article',
#   'http',
#   '20k',
#   '20air',
#   '20emission',
#   '20invent',
#   '20and',
#   '20assesss',
#   '20shep',
#   '20final',
#   '20eis.pdf',
#   'however',
#   'completely',
#   'contradictory',
#   'message'],
#  ['good', 'information', 'thank', 'guyd'],
#  ['helpful', 'not_answer', 'question'],
#  ['see', 'dave', 'ramsey'],
#  ['looking',
#   'find',
#   'information',
#   'what',
#   'kind',
#   'car',
#   'loan',
#   'interest',
#   'rate',
#   'get',
#   'not_credit'],
#  ['not_enough',
#   'variety',
#   'lot',
#   'high-end',
#   u'card',
#   'include',
#   u'benefit',
#   'apr',
#   'annual',
#   u'fee'],
#  ['great', 'work', u'guy', 'keep'],
#  ['what', 'credit', u'card', 'offer', u'benefit', 'music', 'streaming', '?'],
#  ['not_answer', 'question'],
#  [u'contact',
#   'get',
#   'process',
#   'started',
#   'what',
#   'want',
#   'buy',
#   'house',
#   'not_credit',
#   'score',
#   '?'],
#  ['great',
#   'help',
#   'wjho',
#   'money',
#   'low',
#   'income',
#   'people',
#   'banker',
#   'lazy',
#   u'ass',
#   'want',
#   u'u',
#   'make',
#   u'job',
#   'easy',
#   'going',
#   'debt',
#   'juzst',
#   'prove',
#   'make',
#   u'payment',
#   'time',
#   'sad',
#   'process'],
#  ['great',
#   'article',
#   'negative',
#   'thing',
#   'card',
#   'would',
#   u'well',
#   'fargo',
#   u'refuse',
#   'refund',
#   'deposit',
#   'upgrade',
#   'card',
#   u'year',
#   'time',
#   u'payment',
#   'please',
#   'see',
#   'creditkarma',
#   'confirm',
#   'story',
#   u'http',
#   '?',
#   'pg=2',
#   'pgsz=10'],
#  ['im', 'trying', 'build', 'credit', 'help', 'get', 'thr', 'right', 'card'],
#  [],
#  [],
#  [],
#  ['new',
#   'credit',
#   'credit',
#   'card',
#   'still',
#   'trying',
#   'understand',
#   'how',
#   'use',
#   'credit',
#   'card',
#   '200',
#   'limit',
#   'how',
#   'much',
#   'spend',
#   'monthly',
#   'how',
#   'much',
#   'pay',
#   'bill'],
#  ['not_rate', 'fico', u'score'],
#  ['need',
#   'know',
#   'what',
#   'good',
#   u'focus',
#   'score',
#   'know',
#   'good',
#   'credit',
#   'score',
#   '720',
#   'not_idea',
#   'what',
#   'number',
#   'good',
#   u'focus',
#   'score'],
#  ['keep'],
#  ['clear', 'easy', 'understand'],
#  [],
#  ['wanted', 'know', 'what', 'good', 'fico', 'score'],
#  [u'help', 'know', 'information'],
#  ['need', 'know', 'what', '8', u'mean', 'fico', 'score'],
#  ['not_answer', 'specific', 'question', 'gave', 'info'],
#  ['nan'],
#  ['not_tell', 'what', 'good', 'fico', 'score'],
#  ['fico', 'score', '8.', 'good', '?'],
#  ['fico', 'score', '8'],
#  [],
#  ['informative'],
#  ['helpful'],
#  ['informative', 'easy', 'read'],
#  ['not_enough', 'information'],
#  ['need',
#   'loan',
#   'car',
#   'not_time',
#   'raise',
#   'credit',
#   'score',
#   'since',
#   'credit',
#   'monitoring',
#   u'company',
#   'update',
#   'every',
#   '30',
#   u'day',
#   'need',
#   'loan',
#   'obviously',
#   'not_cash',
#   'payment'],
#  [],
#  [],
#  ['need', 'contact', 'number'],
#  ['american', 'express', 'accepted', 'anywhere', '?'],
#  ['limited', 'information'],
#  ['not_enough', 'information', 'income', u'level', 'needed', 'qualify'],
#  ['suck'],
#  ['not_thank'],
#  ['screenshots',
#   'redemtion',
#   'process',
#   'and/or',
#   'detail',
#   'what/how',
#   u'purchase',
#   'coded',
#   'travel'],
#  [u'sound',
#   'like',
#   'limited',
#   'time',
#   u'mile',
#   'expire',
#   '120',
#   u'day',
#   'make',
#   'purchase',
#   'not_roll',
#   'throughout',
#   'year',
#   'would',
#   'seem',
#   'like',
#   'con',
#   'not_pro',
#   'not_think',
#   '?'],
#  [],
#  ['keep'],
#  ['none',
#   'school',
#   u'district',
#   'near',
#   'where',
#   'need',
#   'move',
#   'need',
#   'find',
#   'info',
#   'atlantic',
#   'county'],
#  ['u', 'help', 'establish', 'credit'],
#  ['ineed', 'fico', 'scoreihave', 'slate', 'card'],
#  ['why'],
#  ['misleading', 'empty', 'information'],
#  ['none'],
#  ['not_free', 'credit', u'score', 'credit', 'card', u'cost', 'something'],
#  ['what',
#   'type',
#   'lawyer',
#   'handle',
#   u'case',
#   'like',
#   'cpn',
#   'number',
#   'apply'],
#  ['thank', 'much'],
#  ['information'],
#  ['how', 'apply', 'not_attorney'],
#  ['free',
#   'option',
#   'cpn',
#   'why',
#   'need',
#   'attorney',
#   '?',
#   'why',
#   'ca',
#   'not_tell',
#   'where',
#   'obtain',
#   'one',
#   '?'],
#  ['would',
#   'great',
#   'could',
#   'provide',
#   'calculator',
#   u'display',
#   'finance',
#   'charge',
#   'based',
#   'date',
#   'payment',
#   'opening',
#   'balance',
#   'periodic',
#   'rate',
#   'closing',
#   'date'],
#  ['everything'],
#  ['good', 'article', 'easy', 'understand'],
#  ['yes', 'help', 'people', 'aware', 'misuse', 'credit', 'card'],
#  ['thanks', 'got', 'know', 'how', 'calculation', 'happen'],
#  ['mine',
#   'came',
#   '1679.58',
#   '900',
#   'purchase',
#   'not_sound',
#   'right.is',
#   '?',
#   'almost',
#   'much',
#   'interest',
#   'purchase',
#   'price',
#   'first',
#   'credit',
#   'card'],
#  ['wanted',
#   'know',
#   'how',
#   'intarest',
#   'calculated',
#   'following',
#   'case',
#   'how',
#   'many',
#   u'day',
#   'what',
#   'amount',
#   'previous',
#   'balance',
#   '0',
#   'purchase',
#   'date',
#   '18',
#   'apr',
#   '12k',
#   'statement',
#   'date',
#   '14',
#   'may',
#   '12k',
#   'payment',
#   'date',
#   '8',
#   'june',
#   'paid',
#   '8k',
#   'made',
#   'remaining',
#   '4k',
#   '10',
#   'june',
#   'june',
#   'statement',
#   u'show',
#   'intarest',
#   '298',
#   'monthly',
#   'intarest',
#   'rate',
#   '1.453'],
#  ['want',
#   'know',
#   'what',
#   'would',
#   'monthly',
#   'payment',
#   'line',
#   'credit',
#   'bank',
#   '500.00',
#   u'dollar',
#   '9.99',
#   'interest',
#   'rate',
#   'pay',
#   '4',
#   'month',
#   '?'],
#  ['nothing'],
#  ['love', 'math', 'helpful'],
#  ['want', 'put', 'amount', 'time', 'rate', 'give', 'how', 'much', 'pay'],
#  ['thanks',
#   'making',
#   'understanding',
#   'why',
#   'pay',
#   'cash',
#   'money',
#   u'order',
#   'everything',
#   'buy'],
#  ['understand',
#   'alot',
#   'someone',
#   'low',
#   'iq',
#   'like',
#   'bad',
#   'credit',
#   'already',
#   'not_understand',
#   'hard',
#   'english',
#   'wirds',
#   'like',
#   'actually',
#   'worked',
#   'credit',
#   'card',
#   'company',
#   'using',
#   'big',
#   u'word',
#   'like',
#   'demystify',
#   'intuitive',
#   'still',
#   'people',
#   'who',
#   'not_able',
#   'understand',
#   'still',
#   'lost',
#   'ca',
#   'not_figure',
#   'apr',
#   'messing',
#   'credit',
#   'score',
#   'paying',
#   u'bank',
#   'way',
#   'much',
#   'little',
#   'extra',
#   'help',
#   'needed',
#   'loaning',
#   u'bank',
#   'begin',
#   'sister',
#   'ready',
#   'right',
#   'outta',
#   'high',
#   'school',
#   'honor',
#   'roll',
#   'student',
#   'still',
#   'many',
#   u'question',
#   'reading',
#   'article',
#   'graduating',
#   u'student',
#   'high',
#   'school',
#   'who',
#   'aim',
#   'first',
#   'need',
#   'financial',
#   'help',
#   'going',
#   'world',
#   'impressionable',
#   'oblivious',
#   'pre-college',
#   'real',
#   'world',
#   'borrowing',
#   'credit',
#   'already',
#   'hard'],
#  ['idk'],
#  ['love', 'simplicity', 'complex', 'subject'],
#  ['legal',
#   'add',
#   'interest',
#   u'charge',
#   'interest',
#   'credit',
#   'card',
#   '?',
#   'interest',
#   'added',
#   'principle',
#   'apply',
#   'total',
#   'balance',
#   'including',
#   'interest',
#   'previous',
#   'month',
#   '?'],
#  ['could',
#   'add',
#   'simple',
#   'calculator',
#   'app',
#   'where',
#   'simple',
#   'people',
#   'could',
#   'simply',
#   'punch',
#   'account',
#   'balance',
#   'a.p.r',
#   'fully',
#   'understand',
#   'how',
#   'much',
#   'pay',
#   'monthly',
#   'balance',
#   '?',
#   'figured',
#   'app',
#   'interest',
#   '50.00',
#   'balance',
#   'would',
#   'cost',
#   '3.45',
#   'would',
#   'extremely',
#   'helpful',
#   'could',
#   'punch',
#   u'parent',
#   'end',
#   'month',
#   'balance',
#   'show',
#   'how',
#   'much',
#   'pay',
#   'not_stop',
#   'spending',
#   'foolishly',
#   'appreciate',
#   'note',
#   'fact',
#   'pay',
#   u'le',
#   'interest',
#   'pay',
#   'monthly',
#   'balance',
#   'early',
#   'thank',
#   'work',
#   'done',
#   'subject'],
#  ['balance',
#   'owing',
#   '7,245.00',
#   'interest',
#   'rate',
#   '19.97',
#   'per',
#   'year',
#   'daily',
#   'rate',
#   '0.05456',
#   'march',
#   '1st',
#   '30th',
#   'not_pay',
#   'how',
#   'much',
#   'would',
#   'calculate',
#   '?'],
#  ['keep', 'coming'],
#  ['good', 'explanation'],
#  ['get',
#   'charged',
#   'apr',
#   'balance',
#   'day',
#   'statement',
#   'spend',
#   '1',
#   'today',
#   'pay',
#   'interest',
#   'dollar',
#   'month',
#   'pay',
#   '31st',
#   '?'],
#  ['nice', 'simple'],
#  ['cant', 'find', 'answer', 'looking'],
#  ['well',
#   'laid',
#   'english',
#   'people',
#   'could',
#   'understand',
#   'right',
#   'away',
#   'how',
#   'understand',
#   'interest',
#   'game'],
#  ['informative', 'thank'],
#  ['suck', 'dick'],
#  ['sucked', 'wang'],
#  ['1000',
#   'balance',
#   'statement',
#   'paid',
#   '300',
#   'charge',
#   'interest',
#   '700.what',
#   u'purchase',
#   'make',
#   'next',
#   'month',
#   'not_added',
#   '700',
#   'calculate',
#   'daily',
#   'interest',
#   '?'],
#  ['refines', 'formula', 'computing', 'interest', 'balance'],
#  ['good',
#   u'illustration',
#   'well',
#   'written',
#   'way',
#   'almost',
#   'everyone',
#   'comprehend'],
#  ['thank', 'much', 'credit', 'card', 'company', 'not_able', 'explain'],
#  ['show',
#   'actual',
#   'calculator',
#   'figure',
#   u'user',
#   'plug',
#   'economic',
#   'information'],
#  ['confusing', 'wanted', 'calculator'],
#  ['thx'],
#  ['everything'],
#  [],
#  [u'example', 'especially', 'helpful'],
#  [],
#  ['not_answer', 'question'],
#  ['helpful', 'information', 'thank'],
#  [u'suck'],
#  ['checking', 'button', 'working'],
#  ['thanks', 'what', 'needed', 'know'],
#  ['cvn'],
#  ['wanted',
#   'speak',
#   'live',
#   'representative',
#   'would',
#   'not_allow',
#   'to.also',
#   'ask',
#   'contact',
#   'phone',
#   'number',
#   'not_happen',
#   'either'],
#  [],
#  ['not_make',
#   'much',
#   'sense',
#   'without',
#   'describing',
#   'who',
#   u'card',
#   'best',
#   'tailored'],
#  ['plzz', 'help'],
#  ['not_new', 'information'],
#  ['nice', 'info'],
#  ['wonderful',
#   'site',
#   'information',
#   'english',
#   'totally',
#   'understand',
#   'thank'],
#  ['want',
#   'know',
#   'how',
#   'make',
#   'one',
#   'self',
#   'want',
#   'know',
#   'how',
#   'make',
#   'where',
#   'could',
#   'buy',
#   'stuff'],
#  ['not_looking', 'anan'],
#  ['dating'],
#  ['clear',
#   'thorough',
#   'without',
#   'overwhelmingly',
#   'technical',
#   'bogged',
#   u'minutia',
#   'thanks'],
#  ...]

# %%
def obtain_Message_Token_List(df, category, ngram = 1, split_by = 'page_vertical_tx', messageColumnName = "message", lang = "english", regexPattern = "^[^a-zA-Z0-9]+", pos_tagset = 'universal', specialNotToRemove = set([]), isNormalized = True, isLemmatized = True, stopWordsRemoved = True, handleNegations = True, puncRemoved = True, posTag = True):
    ## Step 1: get the messages perfectly, dealing with weird cases
    messageSet = get_message_set(df, category, split_by = 'page_vertical_tx', messageColumnName = "message")
    if len(messageSet) == 0:
        return []
    else:    
        ## Step 2: Tokenize and (optionally) normalize
        messageToken = tokenize_message_set(messageSet, isNormalized)
        ## Step 3: Remove stop words, punctuation
        ## Step 4: Lemmatize and N-gram (kind of with step 3 too)
        ## Step 5: POS-tag?
        if ngram == 1 and posTag:
            return [nltk.pos_tag(get_ngram_set(message, ngram, isLemmatized = isLemmatized, stopWordsRemoved = stopWordsRemoved, puncRemoved = puncRemoved, regexPattern = regexPattern, lang = lang, specialNotToRemove = specialNotToRemove, handleNegations = handleNegations), tagset = pos_tagset) for message in messageToken]
        else:
            return [get_ngram_set(message, ngram, isLemmatized = isLemmatized, stopWordsRemoved = stopWordsRemoved, puncRemoved = puncRemoved, regexPattern = regexPattern, lang = lang, specialNotToRemove = specialNotToRemove, handleNegations = handleNegations) for message in messageToken]

            
def get_message_set(df, category, split_by = 'page_vertical_tx', messageColumnName = "message"):
    if category != None:
        df = df.loc[df[split_by] == category]
    if len(df.shape) > 0 and df.shape[0] == 0:
        print("Category \'" + str(category) + "\' has no rows. Check spelling.")
        return []
    else:
        return [replaceString(str(message)) for messageL in df[[messageColumnName]].values.tolist() for message in messageL if isASCIIString(replaceString(str(message)))]            

def isASCIIString(string):
    try:
        string.decode('ascii')
        return True
    except:
        return False

# Just some ASCII coding issues
def replaceString(string):
    return string.replace("\\n", " ").replace("&amp;", "&").replace('&#039;', '\'').replace("&quot;", "\"").replace("&lt;", "<").replace("&gt;", ">").replace("\xe2\x80\x93", "-").replace("\xe2\x80\x99", "\'").strip()

# %%
STOPWORD_SET = (set(nltk.corpus.stopwords.words(LANGUAGE)) | set(['even'])) - set(['who', 'why', 'how', 'where', 'when', 'what', 'whom'])

# %%
posts = df.groupby('post_id')
posts.indices
# Out:
# {155648: array([1911]),
#  139265: array([1596]),
#  163842: array([2167, 2168]),
#  192516: array([2996]),
#  90117: array([759, 760, 761, 762, 763, 764, 765, 766, 767]),
#  96262: array([931]),
#  120840: array([1244]),
#  182281: array([2889]),
#  63498: array([277, 278]),
#  174092: array([2498]),
#  262758: array([4740, 4741, 4742, 4743, 4744, 4745, 4746, 4747]),
#  77838: array([554, 555]),
#  221869: array([3584]),
#  49168: array([114, 115]),
#  59409: array([148]),
#  100370: array([1033]),
#  155667: array([1912, 1913]),
#  210964: array([3410, 3411, 3412, 3413, 3414, 3415, 3416, 3417, 3418, 3419, 3420,
#         3421]),
#  151573: array([1798]),
#  79894: array([624]),
#  100377: array([1034]),
#  213453: array([3466, 3467, 3468]),
#  163867: array([2169, 2170, 2171]),
#  203098: array([3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283]),
#  245791: array([4259, 4260, 4261, 4262, 4263, 4264, 4265, 4266, 4267, 4268, 4269,
#         4270, 4271]),
#  188289: array([2941, 2942, 2943, 2944, 2945, 2946, 2947, 2948]),
#  86704: array([707, 708, 709, 710, 711, 712, 713, 714]),
#  151586: array([1799]),
#  59427: array([149]),
#  159647: array([2085, 2086]),
#  143397: array([1656]),
#  75814: array([522, 523, 524, 525, 526]),
#  96295: array([932, 933]),
#  194600: array([3032, 3033, 3034, 3035, 3036, 3037, 3038]),
#  227676: array([3758, 3759]),
#  163883: array([2173]),
#  145452: array([1688, 1689]),
#  156338: array([2005]),
#  163886: array([2174, 2175]),
#  193336: array([3004, 3005, 3006, 3007, 3008, 3009]),
#  221875: array([3585]),
#  151604: array([1801]),
#  163893: array([2176]),
#  263097: array([4750, 4751, 4752, 4753]),
#  245817: array([4272]),
#  143418: array([1657, 1658, 1659, 1660]),
#  163900: array([2177]),
#  100413: array([1035]),
#  127039: array([1317]),
#  79937: array([625, 626, 627]),
#  203718: array([3296]),
#  249581: array([4422, 4423]),
#  160671: array([2104, 2105]),
#  156631: array([2037, 2038, 2039]),
#  96328: array([934, 935, 936, 937]),
#  259909: array([4668]),
#  92236: array([827]),
#  139342: array([1597]),
#  96335: array([938, 939]),
#  215026: array([3541, 3542, 3543]),
#  88146: array([725]),
#  268097: array([4840]),
#  143444: array([1661]),
#  184334: array([2921]),
#  61527: array([207]),
#  155737: array([1920]),
#  196698: array([3097, 3098, 3099, 3100, 3101]),
#  139356: array([1598, 1599]),
#  159837: array([2088]),
#  20574: array([24, 25, 26, 27]),
#  164197: array([2186, 2187, 2188]),
#  259351: array([4659]),
#  162832: array([2144, 2145, 2146]),
#  244753: array([4248]),
#  170052: array([2411, 2412, 2413, 2414, 2415, 2416, 2417, 2418, 2419, 2420]),
#  165993: array([2239]),
#  84075: array([668, 669]),
#  247249: array([4390]),
#  71790: array([401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413,
#         414, 415]),
#  151664: array([1817]),
#  179560: array([2780]),
#  92274: array([828, 829, 830, 831]),
#  157811: array([2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060]),
#  116854: array([1189, 1190, 1191, 1192]),
#  248866: array([4406, 4407, 4408, 4409, 4410, 4411, 4412, 4413, 4414, 4415, 4416,
#         4417, 4418, 4419, 4420]),
#  88184: array([726]),
#  63609: array([279, 280, 281, 282, 283, 284]),
#  247146: array([4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382]),
#  174994: array([2502, 2503]),
#  194687: array([3040, 3041]),
#  116864: array([1193]),
#  233601: array([3852]),
#  245890: array([4273, 4274, 4275, 4276, 4277]),
#  240617: array([3942, 3943]),
#  155781: array([1921]),
#  108679: array([1116]),
#  73865: array([456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468,
#         469, 470]),
#  246321: array([4300, 4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310,
#         4311]),
#  119831: array([1237, 1238]),
#  241439: array([4049, 4050]),
#  208578: array([3375, 3376]),
#  157839: array([2061, 2062]),
#  155792: array([1922, 1923, 1924, 1925, 1926, 1927]),
#  155794: array([1928, 1929]),
#  161939: array([2130]),
#  92185: array([823, 824, 825, 826]),
#  208580: array([3377, 3378, 3379, 3380]),
#  77979: array([558]),
#  143517: array([1663]),
#  203910: array([3303, 3304]),
#  118943: array([1229]),
#  186452: array([2935, 2936]),
#  53409: array([127]),
#  67746: array([342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354,
#         355, 356, 357, 358]),
#  175849: array([2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514,
#         2515]),
#  246632: array([4330, 4331]),
#  155815: array([1930, 1931]),
#  209065: array([3384, 3385, 3386]),
#  114859: array([1170, 1171]),
#  172720: array([2490]),
#  94381: array([880, 881, 882]),
#  221799: array([3583]),
#  155825: array([1932, 1933, 1934, 1935]),
#  168115: array([2319]),
#  75956: array([527, 528, 529]),
#  144376: array([1681, 1682]),
#  207030: array([3354, 3355, 3356, 3357, 3358]),
#  179565: array([2781, 2782]),
#  92344: array([832]),
#  242036: array([4059]),
#  168122: array([2320, 2321]),
#  20667: array([28]),
#  254260: array([4478]),
#  143733: array([1675]),
#  61633: array([208, 209, 210]),
#  59586: array([150]),
#  182987: array([2897, 2898]),
#  92357: array([833, 834, 835, 836, 837]),
#  178375: array([2542, 2543]),
#  170184: array([2421]),
#  143052: array([1645]),
#  165922: array([2238]),
#  160130: array([2090]),
#  243405: array([4192, 4193, 4194, 4195]),
#  59601: array([151, 152]),
#  102610: array([1071]),
#  77859: array([556, 557]),
#  65748: array([329, 330, 331, 332, 333, 334]),
#  239510: array([3912, 3913, 3914, 3915, 3916]),
#  179150: array([2652, 2653, 2654, 2655, 2656, 2657, 2658, 2659, 2660, 2661, 2662,
#         2663]),
#  73945: array([471]),
#  143580: array([1664, 1665]),
#  155869: array([1936, 1937]),
#  100574: array([1036, 1037]),
#  163877: array([2172]),
#  78544: array([590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600]),
#  185765: array([2933, 2934]),
#  110630: array([1125, 1126, 1127, 1128, 1129]),
#  139495: array([1604, 1605]),
#  208618: array([3382]),
#  228122: array([3777, 3778]),
#  243751: array([4198]),
#  155888: array([1938]),
#  172755: array([2491]),
#  155892: array([1939]),
#  181613: array([2885]),
#  168660: array([2348, 2349, 2350, 2351, 2352, 2353]),
#  160127: array([2089]),
#  94461: array([883, 884, 885, 886]),
#  195116: array([3067, 3068, 3069]),
#  138283: array([1558, 1559]),
#  47364: array([109, 110]),
#  143622: array([1666]),
#  151596: array([1800]),
#  69898: array([379, 380, 381, 382]),
#  61707: array([211]),
#  164108: array([2181]),
#  73997: array([472]),
#  78094: array([559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571,
#         572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583]),
#  28943: array([86]),
#  109272: array([1118, 1119]),
#  143637: array([1667]),
#  244686: array([4247]),
#  155928: array([1941]),
#  211893: array([3457]),
#  216726: array([3556, 3557, 3558]),
#  90395: array([768]),
#  156378: array([2012]),
#  137502: array([1342, 1343, 1344, 1345, 1346]),
#  53535: array([128, 129, 130, 131]),
#  211234: array([3423, 3424, 3425, 3426, 3427, 3428, 3429, 3430, 3431, 3432]),
#  59683: array([153]),
#  90404: array([769, 770]),
#  96549: array([940, 941, 942, 943, 944]),
#  169648: array([2409]),
#  143658: array([1668, 1669]),
#  96555: array([945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957,
#         958, 959, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970,
#         971, 972, 973, 974, 975, 976, 977, 978, 979]),
#  229680: array([3784, 3785]),
#  155953: array([1942, 1943, 1944, 1945, 1946]),
#  98612: array([1006]),
#  119094: array([1230]),
#  235913: array([3871, 3872, 3873, 3874]),
#  178069: array([2539, 2540, 2541]),
#  200369: array([3161, 3162, 3163, 3164, 3165, 3166, 3167, 3168, 3169, 3170, 3171,
#         3172, 3173, 3174, 3175, 3176, 3177, 3178, 3179, 3180, 3181, 3182,
#         3183, 3184, 3185, 3186, 3187, 3188, 3189, 3190, 3191, 3192, 3193]),
#  260411: array([4670, 4671, 4672, 4673, 4674, 4675, 4676, 4677, 4678, 4679, 4680,
#         4681, 4682, 4683, 4684, 4685, 4686, 4687, 4688, 4689, 4690, 4691,
#         4692, 4693, 4694, 4695, 4696, 4697, 4698]),
#  268604: array([4841]),
#  143678: array([1670, 1671, 1672]),
#  12607: array([15, 16, 17, 18]),
#  188435: array([2954, 2955]),
#  250177: array([4425]),
#  250178: array([4426, 4427, 4428]),
#  240011: array([3934, 3935, 3936]),
#  247144: array([4373, 4374]),
#  250181: array([4429]),
#  115015: array([1172]),
#  182315: array([2890, 2891]),
#  174410: array([2500]),
#  262905: array([4748, 4749]),
#  164172: array([2182, 2183, 2184]),
#  168270: array([2322, 2323, 2324, 2325, 2326, 2327, 2328, 2329, 2330, 2331, 2332,
#         2333, 2334, 2335]),
#  121167: array([1246, 1247, 1248]),
#  76112: array([530]),
#  203089: array([3275]),
#  176466: array([2517]),
#  139603: array([1606, 1607, 1608, 1609]),
#  260436: array([4699]),
#  115029: array([1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182]),
#  164182: array([2185]),
#  80215: array([628]),
#  174309: array([2499]),
#  51547: array([123]),
#  211292: array([3433, 3434, 3435, 3436, 3437, 3438, 3439]),
#  108893: array([1117]),
#  102751: array([1072]),
#  78176: array([584, 585, 586, 587, 588, 589]),
#  165621: array([2236, 2237]),
#  237878: array([3902]),
#  156005: array([1947]),
#  143719: array([1673, 1674]),
#  156009: array([1948]),
#  221927: array([3587]),
#  154816: array([1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832,
#         1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843]),
#  213357: array([3464]),
#  194673: array([3039]),
#  110961: array([1130, 1131, 1132]),
#  252274: array([4447]),
#  110964: array([1133]),
#  92533: array([838]),
#  143735: array([1676]),
#  164216: array([2189]),
#  80250: array([629, 630]),
#  164219: array([2190, 2191]),
#  244092: array([4212, 4213]),
#  86397: array([700, 701]),
#  239998: array([3932, 3933]),
#  63893: array([285]),
#  244096: array([4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4222, 4223, 4224,
#         4225, 4226, 4227, 4228, 4229, 4230, 4231, 4232, 4233, 4234, 4235,
#         4236, 4237, 4238, 4239, 4240, 4241, 4242, 4243]),
#  31106: array([88, 89, 90]),
#  220421: array([3574]),
#  80262: array([631]),
#  138109: array([1421, 1422, 1423]),
#  238152: array([3903, 3904, 3905]),
#  158679: array([2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078]),
#  143755: array([1677, 1678, 1679, 1680]),
#  119181: array([1231, 1232, 1233, 1234]),
#  76174: array([531]),
#  61839: array([212]),
#  225683: array([3612, 3613]),
#  70037: array([383]),
#  67990: array([359]),
#  169369: array([2407, 2408]),
#  156056: array([1958, 1959]),
#  14745: array([19]),
#  84378: array([670, 671]),
#  121243: array([1249, 1250, 1251]),
#  156060: array([1960, 1961, 1962, 1963, 1964, 1965]),
#  180637: array([2801, 2802, 2803]),
#  158110: array([2064]),
#  61855: array([213, 214, 215, 216, 217, 218]),
#  180640: array([2804, 2805, 2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814,
#         2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825,
#         2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836,
#         2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847,
#         2848]),
#  164257: array([2192, 2193, 2194, 2195, 2196]),
#  213410: array([3465]),
#  82341: array([645]),
#  94630: array([887, 888, 889]),
#  167025: array([2313]),
#  61865: array([219, 220]),
#  260522: array([4700, 4701]),
#  156075: array([1966]),
#  168690: array([2354, 2355]),
#  192735: array([2997]),
#  261749: array([4729, 4730]),
#  61873: array([221]),
#  98738: array([1007, 1008, 1009]),
#  197022: array([3104, 3105, 3106, 3107, 3108, 3109, 3110, 3111, 3112, 3113]),
#  63926: array([286, 287, 288, 289, 290, 291, 292, 293, 294]),
#  178616: array([2551]),
#  264409: array([4759]),
#  88507: array([727]),
#  74173: array([473]),
#  164286: array([2197, 2198]),
#  29119: array([87]),
#  195008: array([3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054,
#         3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, 3064, 3065,
#         3066]),
#  137665: array([1351]),
#  190914: array([2978]),
#  137667: array([1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362,
#         1363, 1364]),
#  171541: array([2444]),
#  126710: array([1314, 1315, 1316]),
#  197025: array([3114, 3115, 3116, 3117, 3118, 3119, 3120, 3121, 3122, 3123, 3124,
#         3125, 3126, 3127, 3128]),
#  197064: array([3130]),
#  104524: array([1098, 1099, 1100]),
#  219595: array([3565, 3566, 3567, 3568, 3569, 3570]),
#  176588: array([2518]),
#  160205: array([2091, 2092, 2093, 2094, 2095, 2096]),
#  209359: array([3390, 3391]),
#  137681: array([1365]),
#  156115: array([1969, 1970, 1971, 1972, 1973, 1974]),
#  201172: array([3205, 3206, 3207, 3208, 3209, 3210, 3211, 3212, 3213, 3214, 3215,
#         3216, 3217, 3218, 3219, 3220, 3221, 3222, 3223, 3224, 3225, 3226,
#         3227, 3228, 3229, 3230, 3231, 3232, 3233, 3234, 3235, 3236, 3237,
#         3238, 3239, 3240, 3241, 3242, 3243, 3244, 3245, 3246, 3247, 3248,
#         3249, 3250, 3251, 3252, 3253, 3254, 3255, 3256]),
#  151630: array([1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812,
#         1813, 1814, 1815, 1816]),
#  205270: array([3329]),
#  137687: array([1366, 1367]),
#  170458: array([2422, 2423]),
#  211420: array([3441, 3442, 3443, 3444, 3445, 3446, 3447, 3448, 3449, 3450, 3451]),
#  156125: array([1975, 1976, 1977, 1978]),
#  145886: array([1697]),
#  9637: array([12, 13]),
#  265024: array([4774]),
#  111074: array([1134]),
#  158179: array([2065, 2066]),
#  88548: array([728]),
#  94696: array([890, 891]),
#  209386: array([3393, 3394, 3395]),
#  244135: array([4244]),
#  155730: array([1914, 1915, 1916, 1917]),
#  150001: array([1742]),
#  137716: array([1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375]),
#  133621: array([1322]),
#  92664: array([839]),
#  155732: array([1918]),
#  253171: array([4471]),
#  190973: array([2979]),
#  137726: array([1376, 1377, 1378]),
#  94720: array([892]),
#  182038: array([2886, 2887, 2888]),
#  246187: array([4278]),
#  246276: array([4279, 4280, 4281, 4282, 4283, 4284]),
#  248863: array([4399, 4400, 4401, 4402, 4403, 4404, 4405]),
#  88587: array([729]),
#  57871: array([138]),
#  262025: array([4735, 4736]),
#  246289: array([4285]),
#  156178: array([1980, 1981, 1982]),
#  264724: array([4760, 4761, 4762, 4763, 4764, 4765, 4766, 4767, 4768, 4769]),
#  94741: array([893]),
#  172568: array([2481, 2482, 2483, 2484, 2485, 2486, 2487, 2488, 2489]),
#  94747: array([894, 895]),
#  74268: array([474, 475, 476, 477, 478, 479]),
#  156034: array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957]),
#  256544: array([4496, 4497, 4498, 4499, 4500]),
#  261480: array([4707, 4708, 4709]),
#  246306: array([4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293, 4294, 4295, 4296,
#         4297, 4298, 4299]),
#  66083: array([335, 336]),
#  258596: array([4646, 4647]),
#  137649: array([1347]),
#  137768: array([1379, 1380]),
#  205353: array([3330, 3331, 3332]),
#  6698: array([8]),
#  156353: array([2006]),
#  178610: array([2550]),
#  59953: array([154]),
#  242226: array([4060]),
#  145971: array([1698]),
#  70196: array([384, 385, 386, 387, 388, 389, 390]),
#  143454: array([1662]),
#  150070: array([1743, 1744]),
#  64055: array([303, 304, 305, 306, 307, 308, 309, 310, 311]),
#  176696: array([2519]),
#  246330: array([4312]),
#  162911: array([2149]),
#  203325: array([3284]),
#  170558: array([2424]),
#  254527: array([4482]),
#  102976: array([1073]),
#  262256: array([4737]),
#  137654: array([1348]),
#  188513: array([2956, 2957, 2958]),
#  80456: array([632, 633]),
#  262729: array([4739]),
#  207434: array([3359]),
#  137804: array([1381]),
#  178765: array([2552, 2553, 2554, 2555, 2556, 2557]),
#  186958: array([2940]),
#  119376: array([1235]),
#  254325: array([4479, 4480, 4481]),
#  199438: array([3154, 3155, 3156]),
#  263510: array([4755]),
#  121431: array([1252, 1253, 1254, 1255, 1256]),
#  246361: array([4316]),
#  246362: array([4317, 4318, 4319, 4320]),
#  156253: array([1984, 1985, 1986, 1987, 1988]),
#  143299: array([1653]),
#  137659: array([1349, 1350]),
#  72292: array([416]),
#  92773: array([840, 841, 842, 843, 844, 845, 846, 847]),
#  137830: array([1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392,
#         1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403,
#         1404, 1405]),
#  179443: array([2746]),
#  260712: array([4702]),
#  237489: array([3897]),
#  237671: array([3900, 3901]),
#  182893: array([2892]),
#  31342: array([91, 92]),
#  238192: array([3906]),
#  168561: array([2336]),
#  70265: array([391]),
#  246394: array([4321, 4322, 4323, 4324, 4325, 4326, 4327, 4328, 4329]),
#  156283: array([1989]),
#  98940: array([1010, 1011, 1012, 1013]),
#  180862: array([2849]),
#  209685: array([3400]),
#  141419: array([1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621]),
#  88708: array([730]),
#  84758: array([672]),
#  169068: array([2386]),
#  164490: array([2199]),
#  90766: array([771]),
#  86671: array([702, 703, 704, 705, 706]),
#  156304: array([1995, 1996]),
#  213650: array([3469]),
#  197059: array([3129]),
#  103060: array([1074, 1075, 1076, 1077]),
#  240957: array([4047]),
#  156310: array([1997]),
#  213655: array([3470, 3471]),
#  76440: array([532, 533]),
#  254617: array([4483, 4484]),
#  258714: array([4653, 4654, 4655]),
#  62109: array([222]),
#  193182: array([3003]),
#  156101: array([1967, 1968]),
#  178848: array([2558, 2559]),
#  179234: array([2680, 2681, 2682, 2683]),
#  242339: array([4062]),
#  178852: array([2560, 2561]),
#  142790: array([1634, 1635]),
#  140401: array([1612]),
#  164520: array([2200]),
#  213675: array([3473]),
#  80556: array([634, 635]),
#  178861: array([2562]),
#  228014: array([3760, 3761, 3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770,
#         3771, 3772, 3773]),
#  170671: array([2425, 2426, 2427, 2428, 2429, 2430, 2431, 2432, 2433]),
#  58032: array([139]),
#  221516: array([3580, 3581, 3582]),
#  155918: array([1940]),
#  163955: array([2178]),
#  94901: array([896]),
#  174775: array([2501]),
#  191162: array([2980]),
#  213680: array([3474]),
#  137918: array([1406]),
#  58144: array([140]),
#  64194: array([312, 313]),
#  178883: array([2563, 2564]),
#  253984: array([4477]),
#  156361: array([2007, 2008, 2009]),
#  176843: array([2520, 2521, 2522, 2523, 2524, 2525, 2526, 2527, 2528, 2529, 2530,
#         2531, 2532]),
#  242382: array([4063]),
#  82639: array([646]),
#  68304: array([360]),
#  255096: array([4486]),
#  156370: array([2010]),
#  115411: array([1183]),
#  156372: array([2011]),
#  62165: array([223, 224, 225, 226]),
#  119511: array([1236]),
#  64216: array([314, 315, 316]),
#  254756: array([4485]),
#  107226: array([1104]),
#  111324: array([1135, 1136]),
#  56031: array([134]),
#  120867: array([1245]),
#  178914: array([2565]),
#  242403: array([4064, 4065, 4066, 4067, 4068, 4069, 4070, 4071, 4072, 4073, 4074,
#         4075, 4076, 4077, 4078, 4079, 4080, 4081, 4082, 4083, 4084, 4085,
#         4086, 4087, 4088, 4089, 4090, 4091, 4092, 4093, 4094, 4095, 4096,
#         4097, 4098, 4099, 4100, 4101, 4102, 4103, 4104, 4105, 4106, 4107,
#         4108, 4109, 4110, 4111, 4112, 4113, 4114, 4115, 4116, 4117, 4118,
#         4119, 4120, 4121, 4122, 4123, 4124, 4125, 4126, 4127, 4128, 4129,
#         4130, 4131, 4132, 4133, 4134, 4135, 4136, 4137, 4138, 4139, 4140,
#         4141, 4142, 4143, 4144, 4145, 4146, 4147, 4148, 4149, 4150, 4151,
#         4152, 4153, 4154, 4155, 4156, 4157, 4158, 4159]),
#  105188: array([1101, 1102]),
#  220842: array([3575]),
#  233887: array([3853]),
#  178924: array([2566]),
#  213742: array([3475, 3476]),
#  60143: array([155, 156, 157, 158, 159, 160, 161]),
#  179243: array([2684, 2685, 2686]),
#  4850: array([2, 3, 4, 5, 6, 7]),
#  252371: array([4448, 4449, 4450, 4451, 4452, 4453, 4454, 4455, 4456, 4457]),
#  178932: array([2567]),
#  255102: array([4487, 4488]),
#  222780: array([3588]),
#  164649: array([2201, 2202, 2203]),
#  258282: array([4643, 4644, 4645]),
#  134271: array([1323]),
#  111356: array([1137, 1138, 1139]),
#  158461: array([2067]),
#  231829: array([3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797, 3798, 3799, 3800,
#         3801, 3802, 3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810, 3811,
#         3812, 3813, 3814, 3815, 3816, 3817, 3818, 3819, 3820]),
#  94976: array([897, 898, 899]),
#  121601: array([1257]),
#  178946: array([2568]),
#  137989: array([1407]),
#  103174: array([1078]),
#  264967: array([4770, 4771, 4772, 4773]),
#  138190: array([1438]),
#  156426: array([2013, 2014, 2015, 2016, 2017]),
#  209367: array([3392]),
#  142092: array([1622]),
#  136750: array([1335]),
#  92942: array([848]),
#  242666: array([4162]),
#  156434: array([2018, 2019]),
#  259203: array([4656, 4657]),
#  90901: array([772, 773]),
#  31510: array([93]),
#  95000: array([900, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912,
#         913, 914, 915, 916, 917, 918]),
#  248031: array([4395]),
#  92954: array([849, 850, 851, 852, 853, 854, 855, 856, 857]),
#  95005: array([919]),
#  97413: array([990, 991, 992, 993]),
#  56096: array([135]),
#  178977: array([2569]),
#  240418: array([3941]),
#  178979: array([2570]),
#  179113: array([2644]),
#  117541: array([1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204,
#         1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212]),
#  140070: array([1610]),
#  138023: array([1408]),
#  99113: array([1014, 1015, 1016]),
#  164992: array([2217]),
#  125063: array([1291, 1292, 1293]),
#  256813: array([4502, 4503, 4504]),
#  196635: array([3096]),
#  255519: array([4491, 4492]),
#  60211: array([162]),
#  244534: array([4246]),
#  139401: array([1600, 1601]),
#  156472: array([2020]),
#  84794: array([673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685,
#         686, 687, 688, 689, 690, 691, 692, 693, 694, 695]),
#  135995: array([1326]),
#  72511: array([417]),
#  179008: array([2573, 2574, 2575, 2576]),
#  76610: array([534]),
#  95043: array([920]),
#  256837: array([4505, 4506]),
#  72520: array([418]),
#  156489: array([2021, 2022, 2023]),
#  223714: array([3597]),
#  160568: array([2098, 2099, 2100, 2101, 2102, 2103]),
#  179030: array([2577]),
#  160328: array([2097]),
#  179032: array([2578]),
#  205657: array([3333, 3334]),
#  179034: array([2579, 2580]),
#  243487: array([4197]),
#  74593: array([480]),
#  228195: array([3779]),
#  207889: array([3360, 3361]),
#  179047: array([2581, 2582, 2583, 2584, 2585, 2586, 2587, 2588, 2589, 2590, 2591,
#         2592, 2593, 2594, 2595, 2596, 2597, 2598, 2599, 2600, 2601, 2602,
#         2603, 2604, 2605, 2606, 2607, 2608, 2609, 2610, 2611, 2612, 2613,
#         2614, 2615, 2616, 2617, 2618, 2619, 2620, 2621, 2622, 2623, 2624,
#         2625, 2626, 2627, 2628, 2629]),
#  138088: array([1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417]),
#  140137: array([1611]),
#  136042: array([1327, 1328, 1329]),
#  166763: array([2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250,
#         2251, 2252, 2253, 2254, 2255, 2256, 2257]),
#  138092: array([1418, 1419]),
#  70509: array([392]),
#  93039: array([858, 859]),
#  74608: array([481]),
#  63976: array([295, 296, 297, 298, 299, 300, 301, 302]),
#  241584: array([4051, 4052, 4053, 4054, 4055]),
#  101235: array([1038]),
#  179060: array([2631, 2632, 2633]),
#  211829: array([3452]),
#  156535: array([2024]),
#  107384: array([1105]),
#  233279: array([3829, 3830, 3831, 3832]),
#  64381: array([317]),
#  179070: array([2634, 2635]),
#  195455: array([3085, 3086, 3087]),
#  111488: array([1140, 1141]),
#  97153: array([980]),
#  179077: array([2636, 2637, 2638, 2639, 2640, 2641, 2642, 2643]),
#  103302: array([1079, 1080]),
#  94017: array([878]),
#  164745: array([2204]),
#  213662: array([3472]),
#  164749: array([2205]),
#  142559: array([1629, 1630, 1631]),
#  220047: array([3571]),
#  156561: array([2025]),
#  99218: array([1017, 1018]),
#  195395: array([3073, 3074, 3075, 3076, 3077, 3078, 3079, 3080, 3081, 3082, 3083,
#         3084]),
#  138134: array([1424]),
#  171747: array([2451]),
#  246680: array([4332, 4333, 4334, 4335, 4336]),
#  72601: array([419, 420, 421, 422]),
#  138138: array([1425, 1426]),
#  91035: array([774, 775]),
#  138140: array([1427, 1428]),
#  158874: array([2079, 2080, 2081]),
#  195486: array([3088, 3089, 3090]),
#  158623: array([2068]),
#  68512: array([361, 362, 363, 364]),
#  72609: array([423]),
#  246690: array([4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344, 4345, 4346, 4347,
#         4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355, 4356, 4357, 4358,
#         4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366, 4367, 4368]),
#  125861: array([1294, 1295, 1296, 1297]),
#  74662: array([482]),
#  156145: array([1979]),
#  58281: array([141]),
#  84906: array([696]),
#  211885: array([3453, 3454, 3455, 3456]),
#  156590: array([2026, 2027, 2028, 2029, 2030]),
#  137032: array([1337, 1338, 1339, 1340]),
#  156594: array([2031]),
#  248809: array([4398]),
#  137241: array([1341]),
#  207006: array([3343]),
#  138166: array([1430]),
#  97207: array([981]),
#  138169: array([1431, 1432, 1433, 1434, 1435, 1436, 1437]),
#  233411: array([3851]),
#  179132: array([2645, 2646, 2647, 2648, 2649, 2650]),
#  148413: array([1702]),
#  164798: array([2206]),
#  242740: array([4163]),
#  74689: array([483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495,
#         496, 497, 498, 499, 500, 501, 502]),
#  247241: array([4389]),
#  248771: array([4397]),
#  154564: array([1818, 1819, 1820, 1821]),
#  252383: array([4458, 4459, 4460, 4461, 4462, 4463, 4464, 4465, 4466, 4467, 4468]),
#  64454: array([318]),
#  250392: array([4430]),
#  148424: array([1703, 1704, 1705]),
#  156617: array([2035, 2036]),
#  136139: array([1330, 1331]),
#  177100: array([2533]),
#  207010: array([3344, 3345, 3346, 3347, 3348, 3349, 3350, 3351, 3352, 3353]),
#  72654: array([424, 425]),
#  177106: array([2534]),
#  138196: array([1439, 1440]),
#  164821: array([2207]),
#  95191: array([921, 922]),
#  164824: array([2208, 2209, 2210]),
#  179161: array([2664]),
#  82906: array([647, 648, 649]),
#  156636: array([2041]),
#  156638: array([2042]),
#  138208: array([1441, 1442, 1443, 1444, 1445]),
#  99299: array([1019]),
#  138214: array([1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456,
#         1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467,
#         1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478,
#         1479, 1480, 1481, 1482]),
#  168935: array([2380, 2381, 2382, 2383, 2384, 2385]),
#  167999: array([2318]),
#  148458: array([1706]),
#  148459: array([1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716]),
#  72686: array([426, 427]),
#  179184: array([2667]),
#  64498: array([320]),
#  70643: array([393]),
#  93173: array([860]),
#  138230: array([1490, 1491, 1492, 1493, 1494, 1495, 1496, 1497]),
#  95223: array([923]),
#  139493: array([1602, 1603]),
#  205817: array([3335, 3336]),
#  179194: array([2668]),
#  138235: array([1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505]),
#  179196: array([2669, 2670]),
#  80893: array([636, 637]),
#  93182: array([861, 862, 863, 864]),
#  138240: array([1506]),
#  179203: array([2671]),
#  87044: array([715]),
#  209925: array([3401]),
#  179207: array([2672, 2673, 2674, 2675, 2676, 2677, 2678, 2679]),
#  203607: array([3285, 3286, 3287, 3288, 3289, 3290, 3291, 3292, 3293, 3294, 3295]),
#  78860: array([601]),
#  211982: array([3458, 3459]),
#  138255: array([1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517,
#         1518, 1519, 1520, 1521]),
#  115728: array([1184]),
#  138257: array([1522]),
#  93203: array([865]),
#  214919: array([3481, 3482]),
#  199622: array([3160]),
#  97302: array([982, 983, 984, 985, 986, 987, 988, 989]),
#  46103: array([97]),
#  238616: array([3907]),
#  138265: array([1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531]),
#  179375: array([2724, 2725]),
#  138268: array([1532]),
#  85021: array([697]),
#  93215: array([866, 867]),
#  138272: array([1533]),
#  185377: array([2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929]),
#  138274: array([1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544,
#         1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555,
#         1556]),
#  74787: array([503, 504, 505, 506, 507]),
#  138276: array([1557]),
#  161969: array([2131, 2132]),
#  70696: array([394]),
#  207913: array([3362, 3363]),
#  113707: array([1159]),
#  197682: array([3131, 3132]),
#  148531: array([1717, 1718]),
#  189492: array([2965]),
#  178981: array([2571]),
#  232502: array([3825, 3826]),
#  171064: array([2435, 2436, 2437, 2438, 2439]),
#  179257: array([2687, 2688, 2689, 2690, 2691, 2692, 2693, 2694, 2695, 2696, 2697,
#         2698]),
#  68668: array([365, 366, 367, 368, 369, 370, 371]),
#  193166: array([2999, 3000, 3001, 3002]),
#  179266: array([2699, 2700, 2701, 2702, 2703, 2704, 2705, 2706, 2707]),
#  232515: array([3827, 3828]),
#  164932: array([2212]),
#  224327: array([3598, 3599, 3600, 3601, 3602, 3603]),
#  83019: array([650, 651, 652]),
#  216012: array([3544]),
#  267341: array([4837]),
#  179278: array([2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716, 2717, 2718,
#         2719, 2720, 2721, 2722]),
#  70735: array([395]),
#  132177: array([1320]),
#  150611: array([1745]),
#  162901: array([2147, 2148]),
#  261678: array([4728]),
#  178573: array([2544, 2545, 2546, 2547, 2548, 2549]),
#  58457: array([142, 143, 144, 145, 146]),
#  138767: array([1578]),
#  183388: array([2899]),
#  181341: array([2852]),
#  244382: array([4245]),
#  50271: array([116]),
#  226400: array([3614]),
#  68707: array([372, 373]),
#  164964: array([2213, 2214, 2215, 2216]),
#  155494: array([1880]),
#  251409: array([4436]),
#  240086: array([3938, 3939]),
#  246889: array([4370]),
#  150636: array([1746]),
#  228461: array([3780]),
#  89200: array([731, 732, 733]),
#  136305: array([1332]),
#  260886: array([4703]),
#  251411: array([4437, 4438]),
#  265046: array([4775, 4776]),
#  74870: array([508]),
#  217961: array([3562]),
#  185464: array([2930]),
#  107642: array([1106]),
#  171199: array([2440, 2441, 2442]),
#  265340: array([4777, 4778, 4779, 4780, 4781, 4782, 4783, 4784, 4785]),
#  179050: array([2630]),
#  195214: array([3070, 3071, 3072]),
#  126485: array([1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312]),
#  138368: array([1560, 1561, 1562, 1563, 1564, 1565]),
#  150720: array([1747]),
#  256875: array([4508, 4509]),
#  263300: array([4754]),
#  74885: array([509, 510, 511, 512, 513, 514, 515, 516]),
#  169094: array([2387]),
#  89281: array([734, 735]),
#  83081: array([653]),
#  234108: array([3854, 3855]),
#  60556: array([163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175,
#         176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186]),
#  165005: array([2218, 2219, 2220]),
#  166765: array([2258]),
#  220304: array([3572, 3573]),
#  165009: array([2221]),
#  244885: array([4249]),
#  252431: array([4469, 4470]),
#  46233: array([98]),
#  136346: array([1333, 1334]),
#  117916: array([1213, 1214, 1215, 1216, 1217]),
#  101533: array([1039]),
#  243293: array([4174, 4175, 4176, 4177, 4178, 4179, 4180, 4181, 4182, 4183, 4184,
#         4185, 4186, 4187, 4188, 4189, 4190, 4191]),
#  179359: array([2723]),
#  208032: array([3364, 3365]),
#  206363: array([3337, 3338]),
#  81060: array([638, 639, 640]),
#  244907: array([4250, 4251]),
#  178985: array([2572]),
#  138781: array([1579]),
#  188813: array([2960, 2961]),
#  81074: array([641, 642, 643]),
#  166771: array([2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269,
#         2270, 2271, 2272, 2273, 2274, 2275, 2276, 2277, 2278, 2279, 2280,
#         2281, 2282, 2283, 2284, 2285, 2286, 2287, 2288, 2289, 2290, 2291,
#         2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299, 2300, 2301, 2302,
#         2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310]),
#  99508: array([1020]),
#  240222: array([3940]),
#  165047: array([2222]),
#  255160: array([4489, 4490]),
#  262004: array([4734]),
#  142522: array([1623]),
#  244923: array([4252]),
#  179388: array([2726]),
#  27839: array([85]),
#  142528: array([1624, 1625, 1626, 1627, 1628]),
#  91329: array([780, 781, 782]),
#  165058: array([2223, 2224]),
#  193731: array([3013]),
#  259269: array([4658]),
#  266785: array([4836]),
#  179400: array([2727]),
#  244937: array([4253, 4254, 4255]),
#  168823: array([2356, 2357, 2358, 2359, 2360, 2361, 2362, 2363, 2364, 2365, 2366,
#         2367, 2368, 2369, 2370, 2371, 2372, 2373, 2374, 2375, 2376, 2377,
#         2378, 2379]),
#  89293: array([736]),
#  240846: array([3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952, 3953, 3954,
#         3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963, 3964, 3965,
#         3966, 3967, 3968, 3969, 3970, 3971, 3972, 3973, 3974, 3975, 3976,
#         3977, 3978, 3979, 3980, 3981, 3982, 3983, 3984, 3985, 3986, 3987,
#         3988, 3989, 3990, 3991, 3992, 3993, 3994, 3995, 3996, 3997, 3998,
#         3999, 4000, 4001, 4002, 4003, 4004, 4005, 4006, 4007, 4008, 4009,
#         4010, 4011, 4012, 4013, 4014, 4015, 4016, 4017, 4018, 4019, 4020,
#         4021, 4022, 4023, 4024, 4025, 4026, 4027, 4028, 4029, 4030, 4031,
#         4032, 4033, 4034, 4035, 4036, 4037, 4038, 4039, 4040, 4041, 4042,
#         4043, 4044, 4045, 4046]),
#  173261: array([2492, 2493, 2494, 2495, 2496]),
#  111824: array([1142]),
#  138104: array([1420]),
#  251094: array([4431]),
#  261182: array([4704]),
#  113881: array([1160, 1161, 1162, 1163]),
#  243919: array([4199, 4200, 4201, 4202, 4203, 4204, 4205, 4206, 4207, 4208]),
#  179420: array([2728, 2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738,
#         2739, 2740, 2741, 2742]),
#  150750: array([1748]),
#  40159: array([96]),
#  101601: array([1040]),
#  179426: array([2744]),
#  156654: array([2043]),
#  169188: array([2388]),
#  66791: array([337, 338, 339, 340]),
#  155516: array([1881]),
#  83178: array([654]),
#  242333: array([4061]),
#  89327: array([737]),
#  267504: array([4838]),
#  158961: array([2082]),
#  191730: array([2981]),
#  164051: array([2179, 2180]),
#  256935: array([4510, 4511]),
#  248206: array([4396]),
#  138489: array([1566, 1567]),
#  239533: array([3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924]),
#  265469: array([4786, 4787, 4788, 4789, 4790, 4791, 4792, 4793, 4794, 4795, 4796,
#         4797, 4798, 4799, 4800, 4801, 4802, 4803, 4804, 4805, 4806, 4807,
#         4808, 4809, 4810, 4811, 4812, 4813, 4814, 4815, 4816, 4817, 4818,
#         4819, 4820, 4821, 4822, 4823, 4824, 4825, 4826, 4827, 4828, 4829,
#         4830, 4831]),
#  181504: array([2871]),
#  261300: array([4705, 4706]),
#  97541: array([994]),
#  72966: array([428, 429, 430, 431, 432, 433, 434, 435, 436, 437]),
#  63361: array([259, 260]),
#  179465: array([2747]),
#  169226: array([2389]),
#  179467: array([2748]),
#  142605: array([1632]),
#  179470: array([2749]),
#  99602: array([1021]),
#  122414: array([1261]),
#  165142: array([2225]),
#  179479: array([2753, 2754, 2755, 2756, 2757]),
#  107802: array([1107, 1108, 1109, 1110]),
#  97564: array([995]),
#  253214: array([4472, 4473, 4474]),
#  225157: array([3608, 3609]),
#  77088: array([535, 536]),
#  236835: array([3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882, 3883, 3884, 3885,
#         3886, 3887, 3888]),
#  77092: array([537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549,
#         550, 551]),
#  179495: array([2758]),
#  202024: array([3257, 3258, 3259, 3260, 3261, 3262, 3263, 3264, 3265, 3266, 3267]),
#  64809: array([321]),
#  169310: array([2390, 2391, 2392, 2393]),
#  179499: array([2759]),
#  189744: array([2966, 2967, 2968]),
#  181553: array([2877, 2878]),
#  138546: array([1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575]),
#  243251: array([4169, 4170, 4171, 4172, 4173]),
#  68916: array([374, 375]),
#  179510: array([2760]),
#  150839: array([1749, 1750, 1751]),
#  237108: array([3895]),
#  155735: array([1919]),
#  132319: array([1321]),
#  179516: array([2764, 2765, 2766]),
#  87357: array([716, 717, 718, 719, 720, 721, 722, 723]),
#  122174: array([1258]),
#  46399: array([99]),
#  101697: array([1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051,
#         1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062,
#         1063, 1064, 1065, 1066, 1067]),
#  186720: array([2937, 2938, 2939]),
#  179526: array([2767, 2768]),
#  179425: array([2743]),
#  229114: array([3781]),
#  142983: array([1641, 1642, 1643]),
#  171557: array([2450]),
#  251214: array([4432, 4433, 4434]),
#  179535: array([2769]),
#  89424: array([738, 739]),
#  179427: array([2745]),
#  179541: array([2771, 2772]),
#  181590: array([2883, 2884]),
#  120151: array([1239]),
#  179545: array([2773, 2774]),
#  150875: array([1752]),
#  118330: array([1222, 1223, 1224, 1225]),
#  93534: array([868]),
#  120159: array([1240]),
#  143248: array([1648, 1649]),
#  179554: array([2775, 2776]),
#  179771: array([2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793, 2794, 2795,
#         2796, 2797]),
#  169316: array([2394, 2395, 2396, 2397, 2398, 2399, 2400, 2401, 2402, 2403, 2404,
#         2405, 2406]),
#  216421: array([3552, 3553]),
#  179558: array([2779]),
#  151031: array([1775]),
#  150888: array([1753]),
#  60777: array([187, 188, 189, 190, 191, 192, 193, 194, 195]),
#  234858: array([3856]),
#  101739: array([1068]),
#  143250: array([1650, 1651, 1652]),
#  223455: array([3593]),
#  243056: array([4166, 4167, 4168]),
#  196927: array([3102, 3103]),
#  245415: array([4257, 4258]),
#  163188: array([2150, 2151, 2152]),
#  118133: array([1218, 1219, 1220, 1221]),
#  179574: array([2783, 2784]),
#  148855: array([1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729]),
#  148856: array([1730, 1731, 1732]),
#  230217: array([3786]),
#  181482: array([2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863,
#         2864, 2865, 2866, 2867, 2868, 2869, 2870]),
#  150911: array([1754]),
#  168571: array([2337, 2338, 2339, 2340, 2341, 2342, 2343, 2344, 2345, 2346, 2347]),
#  253314: array([4475]),
#  184214: array([2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914,
#         2915, 2916, 2917]),
#  234888: array([3857]),
#  234890: array([3858, 3859, 3860, 3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868]),
#  263896: array([4756, 4757, 4758]),
#  185741: array([2932]),
#  142735: array([1633]),
#  232117: array([3821, 3822, 3823, 3824]),
#  183698: array([2900]),
#  116118: array([1185]),
#  101784: array([1069]),
#  46489: array([100, 101, 102, 103, 104, 105, 106]),
#  155035: array([1844]),
#  210333: array([3402]),
#  161876: array([2122, 2123, 2124, 2125, 2126, 2127, 2128, 2129]),
#  245153: array([4256]),
#  214435: array([3478, 3479]),
#  73124: array([438, 439]),
#  62885: array([227]),
#  247152: array([4385, 4386, 4387, 4388]),
#  216092: array([3550, 3551]),
#  246721: array([4369]),
#  150961: array([1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765,
#         1766, 1767, 1768, 1769, 1770, 1771, 1772]),
#  79283: array([602]),
#  93620: array([869, 870, 871, 872]),
#  150965: array([1773]),
#  251318: array([4435]),
#  183737: array([2901, 2902, 2903]),
#  126394: array([1298, 1299, 1300, 1301]),
#  138683: array([1576]),
#  239893: array([3930, 3931]),
#  243030: array([4164, 4165]),
#  171459: array([2443]),
#  180631: array([2800]),
#  247149: array([4383, 4384]),
#  101830: array([1070]),
#  116167: array([1186, 1187]),
#  208328: array([3366]),
#  209484: array([3396, 3397, 3398, 3399]),
#  261579: array([4710, 4711, 4712]),
#  256533: array([4493, 4494, 4495]),
#  261581: array([4713]),
#  208335: array([3367]),
#  91601: array([796]),
#  150994: array([1774]),
#  67027: array([341]),
#  126422: array([1302, 1303, 1304]),
#  91610: array([797]),
#  79323: array([603, 604, 605, 606]),
#  77276: array([552]),
#  138149: array([1429]),
#  156240: array([1983]),
#  155536: array([1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892,
#         1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903]),
#  247422: array([4392, 4393]),
#  149414: array([1736, 1737, 1738, 1739, 1740, 1741]),
#  142822: array([1636, 1637, 1638, 1639]),
#  239080: array([3908, 3909]),
#  202218: array([3268, 3269, 3270, 3271, 3272, 3273, 3274]),
#  242599: array([4160, 4161]),
#  93678: array([873, 874, 875, 876, 877]),
#  114159: array([1164, 1165, 1166, 1167]),
#  247280: array([4391]),
#  149075: array([1733, 1734, 1735]),
#  73204: array([440, 441, 442]),
#  7081: array([ 9, 10, 11]),
#  259568: array([4666, 4667]),
#  151033: array([1776, 1777, 1778, 1779, 1780, 1781]),
#  99835: array([1022, 1023]),
#  120318: array([1241]),
#  138752: array([1577]),
#  164880: array([2211]),
#  214956: array([3483, 3484, 3485, 3486, 3487, 3488, 3489, 3490, 3491, 3492, 3493,
#         3494, 3495, 3496, 3497, 3498, 3499, 3500, 3501, 3502, 3503, 3504,
#         3505, 3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 3514, 3515,
#         3516, 3517, 3518, 3519, 3520, 3521, 3522, 3523, 3524, 3525, 3526]),
#  179474: array([2750, 2751, 2752]),
#  249431: array([4421]),
#  73230: array([443, 444]),
#  71183: array([396]),
#  120408: array([1242]),
#  239875: array([3925, 3926, 3927, 3928, 3929]),
#  91669: array([798, 799, 800, 801, 802, 803, 804, 805, 806, 807]),
#  237078: array([3889, 3890, 3891, 3892, 3893, 3894]),
#  83481: array([655, 656]),
#  171547: array([2445, 2446, 2447, 2448, 2449]),
#  247943: array([4394]),
#  122397: array([1259, 1260]),
#  91678: array([808, 809, 810, 811, 812, 813, 814, 815, 816]),
#  ...}
